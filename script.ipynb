# %%
import os
import cv2
import numpy as np
import pytesseract
import tkinter as tk
from tkinter import filedialog, messagebox
from PIL import Image, ImageEnhance
import shutil

# %% [markdown]
# Funzione process_image:
#
# Converte l'immagine in scala di grigi.
# Applica la sogliatura adattiva per ottenere un'immagine binarizzata.
# Rimuove il rumore dall'immagine binarizzata.
# Applica operazioni morfologiche per migliorare la forma dei caratteri.
# Estrae i caratteri rilevati dall'immagine e li salva come immagini separate nella cartella di output. Disegna anche dei rettangoli intorno ai caratteri nell'immagine originale per mostrare i caratteri rilevati.
# Salva l'immagine originale con i rettangoli e l'immagine binarizzata con i caratteri rilevati.

# %%
import os
import cv2
import numpy as np
import tkinter as tk
from tkinter import filedialog, messagebox

def process_image(image_path, output_path):
    if not os.path.exists(image_path):
        print(f"Errore: il file {image_path} non esiste.")
        return

    im = cv2.imread(image_path)

    if im is None:
        print(f"Errore durante la lettura dell'immagine: {image_path}")
        return

    base_name = os.path.splitext(os.path.basename(image_path))[0]

    # Converti in scala di grigi
    im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)

    # Apply adaptive thresholding
    bw = cv2.adaptiveThreshold(im_gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 15, 8)

    # Denoise image
    bw = cv2.fastNlMeansDenoising(bw, None, 30, 7, 21)

    # Morphological operations to separate characters better
    kernel_dilate = np.ones((2, 2), np.uint8)
    kernel_erode = np.ones((1, 1), np.uint8)
    bw = cv2.erode(bw, kernel_erode, iterations=1)
    bw = cv2.dilate(bw, kernel_dilate, iterations=1)

    # Find contours to detect characters
    contours, _ = cv2.findContours(bw, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Sorting contours from left to right
    contours = sorted(contours, key=lambda ctr: cv2.boundingRect(ctr)[0])

    # Save the image without rectangles
    cv2.imwrite(os.path.join(output_path, f'{base_name}_out_without_rectangles.png'), im_gray)

    # Draw rectangles on the original image
    im_with_rectangles = im.copy()
    for i, ctr in enumerate(contours):
        x, y, w, h = cv2.boundingRect(ctr)
        char_img = im_gray[y:y+h, x:x+w]
        cv2.imwrite(os.path.join(output_path, f'{base_name}_char_{i}.jpg'), char_img)
        cv2.rectangle(im_with_rectangles, (x, y), (x+w, y+h), (0, 255, 0), 2)

    # Save the images with and without rectangles
    cv2.imwrite(os.path.join(output_path, f'{base_name}_out.png'), im_with_rectangles)
    cv2.imwrite(os.path.join(output_path, f'{base_name}_out_bw.png'), bw)

def select_input_directory():
    dir_path = filedialog.askdirectory(title="Seleziona la directory di input")
    if dir_path:
        input_dir.set(dir_path)

def select_output_directory():
    dir_path = filedialog.askdirectory(title="Seleziona la directory di output")
    if dir_path:
        output_dir.set(dir_path)

def process_all_images():
    input_path = input_dir.get()
    output_path = output_dir.get()
    if not input_path or not output_path:
        messagebox.showwarning("Attenzione", "Per favore seleziona sia la directory di input che quella di output")
        return

    supported_formats = (".tif", ".jpg", ".jpeg", ".png")
    for filename in os.listdir(input_path):
        if filename.lower().endswith(supported_formats): 
            full_input_path = os.path.join(input_path, filename)
            full_output_path = os.path.join(output_path, filename.split('.')[0])
            os.makedirs(full_output_path, exist_ok=True)
            process_image(full_input_path, full_output_path) 

    messagebox.showinfo("Completato", "Elaborazione completata!")

app = tk.Tk()
app.title("Image Processing Batch")

input_dir = tk.StringVar()
output_dir = tk.StringVar()

frame = tk.Frame(app)
frame.pack(padx=10, pady=10)

input_label = tk.Label(frame, text="Directory di input:")
input_label.grid(row=0, column=0, sticky="e")
input_entry = tk.Entry(frame, textvariable=input_dir, width=50)
input_entry.grid(row=0, column=1, padx=5)
input_button = tk.Button(frame, text="Sfoglia...", command=select_input_directory)
input_button.grid(row=0, column=2)

output_label = tk.Label(frame, text="Directory di output:")
output_label.grid(row=1, column=0, sticky="e")
output_entry = tk.Entry(frame, textvariable=output_dir, width=50)
output_entry.grid(row=1, column=1, padx=5)
output_button = tk.Button(frame, text="Sfoglia...", command=select_output_directory)
output_button.grid(row=1, column=2)

process_button = tk.Button(app, text="Processa tutte le immagini", command=process_all_images)
process_button.pack(pady=10)

app.mainloop()

# %%
drawing = False
ix, iy = -1, -1
fx, fy = -1, -1

def draw_rectangle(event, x, y, flags, param):
    global ix, iy, fx, fy, drawing, im_contours

    output_dir, characters, image_name = param

    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
        ix, iy = x, y

    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing:
            fx, fy = x, y

    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        fx, fy = x, y

        # Controllo per assicurarsi che i punti del rettangolo siano all'interno dei limiti dell'immagine
        if ix < 0:
            ix = 0
        if iy < 0:
            iy = 0
        if fx >= im.shape[1]:
            fx = im.shape[1] - 1
        if fy >= im.shape[0]:
            fy = im.shape[0] - 1
        
        if ix < fx and iy < fy:
            cv2.rectangle(im_contours, (ix, iy), (fx, fy), (0, 0, 255), 2)
            roi = im[iy:fy, ix:fx]
            output_path = os.path.join(output_dir, f'{image_name}_character_{len(characters) + 1}.png')
            cv2.imwrite(output_path, roi)
            characters.append(output_path)

def detect_characters(image_path, output_dir=None):
    global im, im_contours

    if output_dir is None:
        output_dir = 'extracted_characters'
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    im = cv2.imread(image_path)
    if im is None:
        print(f"Errore durante la lettura dell'immagine: {image_path}")
        return

    h, w = im.shape[:2]
    im_contours = im.copy()
    im = cv2.cvtColor(im_contours, cv2.COLOR_BGR2GRAY)
    window_name = 'Contours with Bounding Boxes'
    cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
    cv2.resizeWindow(window_name,200, 100)

    image_name = os.path.splitext(os.path.basename(image_path))[0]
    output_dir = output_dir_entry.get()
    characters = []

    cv2.setMouseCallback(window_name, draw_rectangle, param=(output_dir, characters, image_name))

    while True:
        cv2.imshow(window_name, im)
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('0'):
            break

    cv2.destroyAllWindows()

def select_image_file():
    file_path = filedialog.askopenfilename(filetypes=[("Image files", "*.jpg *.jpeg *.png *.tif *.bmp")])
    if file_path:
        image_path_entry.delete(0, tk.END)
        image_path_entry.insert(0, file_path)

def select_output_directory():
    dir_path = filedialog.askdirectory()
    if dir_path:
        output_dir_entry.delete(0, tk.END)
        output_dir_entry.insert(0, dir_path)

def start_extraction():
    image_path = image_path_entry.get()
    output_dir = output_dir_entry.get()
    
    if not image_path or not output_dir:
        messagebox.showerror("Errore", "Seleziona un'immagine e una directory di output.")
        return
    
    detect_characters(image_path, output_dir)
    messagebox.showinfo("Successo", "Estrazione dei caratteri completata.")

# Configurazione dell'interfaccia grafica
root = tk.Tk()
root.title("Estrattore di Caratteri")
root.geometry("600x200")

tk.Label(root, text="Seleziona l'immagine:").grid(row=0, column=0, padx=10, pady=5)
image_path_entry = tk.Entry(root, width=50)
image_path_entry.grid(row=0, column=1, padx=10, pady=5)
tk.Button(root, text="Sfoglia", command=select_image_file).grid(row=0, column=2, padx=10, pady=5)

tk.Label(root, text="Seleziona la directory di output:").grid(row=1, column=0, padx=10, pady=5)
output_dir_entry = tk.Entry(root, width=50)
output_dir_entry.grid(row=1, column=1, padx=10, pady=5)
tk.Button(root, text="Sfoglia", command=select_output_directory).grid(row=1, column=2, padx=10, pady=5)

tk.Button(root, text="Avvia estrazione", command=start_extraction).grid(row=2, column=1, padx=10, pady=20)

root.mainloop()

# %% [markdown]
# <H1>SCRIPT PER L'ELABORAZONE DI SINGOLE IMMAGINI O IN BATCH </H1>

# %%
drawing = False
ix, iy = -1, -1
fx, fy = -1, -1

def process_image(image_path, output_path):
    if not os.path.exists(image_path):
        print(f"Errore: il file {image_path} non esiste.")
        return

    im = cv2.imread(image_path)

    if im is None:
        print(f"Errore durante la lettura dell'immagine: {image_path}")
        return

    base_name = os.path.splitext(os.path.basename(image_path))[0]

    # Converti in scala di grigi
    im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)

    # Apply adaptive thresholding
    bw = cv2.adaptiveThreshold(im_gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 15, 8)

    # Denoise image
    bw = cv2.fastNlMeansDenoising(bw, None, 30, 7, 21)

    # Morphological operations to separate characters better
    kernel_dilate = np.ones((2, 2), np.uint8)
    kernel_erode = np.ones((1, 1), np.uint8)
    bw = cv2.erode(bw, kernel_erode, iterations=1)
    bw = cv2.dilate(bw, kernel_dilate, iterations=1)

    # Find contours to detect characters
    contours, _ = cv2.findContours(bw, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Sorting contours from left to right
    contours = sorted(contours, key=lambda ctr: cv2.boundingRect(ctr)[0])

    # Save the image without rectangles
    cv2.imwrite(os.path.join(output_path, f'{base_name}_out_without_rectangles.png'), im_gray)

    # Draw rectangles on the original image
    im_with_rectangles = im.copy()
    for i, ctr in enumerate(contours):
        x, y, w, h = cv2.boundingRect(ctr)
        char_img = im_gray[y:y+h, x:x+w]
        cv2.imwrite(os.path.join(output_path, f'{base_name}_char_{i}.jpg'), char_img)
        cv2.rectangle(im_with_rectangles, (x, y), (x+w, y+h), (0, 255, 0), 2)

    # Save the images with and without rectangles
    cv2.imwrite(os.path.join(output_path, f'{base_name}_out.png'), im_with_rectangles)
    cv2.imwrite(os.path.join(output_path, f'{base_name}_out_bw.png'), bw)

def select_input_directory():
    dir_path = filedialog.askdirectory(title="Seleziona la directory di input")
    if dir_path:
        input_dir.set(dir_path)

def select_output_directory():
    dir_path = filedialog.askdirectory(title="Seleziona la directory di output")
    if dir_path:
        if mode_var.get() == 1:
            single_output_dir.set(dir_path)
        else:
            batch_output_dir.set(dir_path)

def process_all_images():
    input_path = input_dir.get()
    output_path = batch_output_dir.get()
    if not input_path or not output_path:
        messagebox.showwarning("Attenzione", "Per favore seleziona sia la directory di input che quella di output")
        return

    supported_formats = (".tif", ".jpg", ".jpeg", ".png")
    for filename in os.listdir(input_path):
        if filename.lower().endswith(supported_formats): 
            full_input_path = os.path.join(input_path, filename)
            full_output_path = os.path.join(output_path, filename.split('.')[0])
            os.makedirs(full_output_path, exist_ok=True)
            process_image(full_input_path, full_output_path) 

    messagebox.showinfo("Completato", "Elaborazione completata!")

def draw_rectangle(event, x, y, flags, param):
    global ix, iy, fx, fy, drawing, im_contours

    output_dir, characters, image_name = param

    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
        ix, iy = x, y

    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing:
            fx, fy = x, y
            im_temp = im_contours.copy()
            cv2.rectangle(im_temp, (ix, iy), (fx, fy), (0, 0, 255), 2)
            cv2.imshow('Contours with Bounding Boxes', im_temp)

    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        fx, fy = x, y

        if ix < 0:
            ix = 0
        if iy < 0:
            iy = 0
        if fx >= im.shape[1]:
            fx = im.shape[1] - 1
        if fy >= im.shape[0]:
            fy = im.shape[0] - 1
        
        if ix < fx and iy < fy:
            cv2.rectangle(im_contours, (ix, iy), (fx, fy), (0, 0, 255), 2)
            roi = im[iy:fy, ix:fx]
            output_path = os.path.join(output_dir, f'{image_name}_character_{len(characters) + 1}.png')
            cv2.imwrite(output_path, roi)
            characters.append(output_path)
            cv2.imshow('Contours with Bounding Boxes', im_contours)

def detect_characters(image_path, output_dir=None):
    global im, im_contours

    if output_dir is None:
        output_dir = 'extracted_characters'
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    im = cv2.imread(image_path)
    if im is None:
        print(f"Errore durante la lettura dell'immagine: {image_path}")
        return

    h, w = im.shape[:2]
    im_contours = im.copy()
    im = cv2.cvtColor(im_contours, cv2.COLOR_BGR2GRAY)
    window_name = 'Contours with Bounding Boxes'
    cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
    cv2.resizeWindow(window_name, 800,1000)

    image_name = os.path.splitext(os.path.basename(image_path))[0]
    output_dir = single_output_dir.get()
    characters = []

    cv2.setMouseCallback(window_name, draw_rectangle, param=(output_dir, characters, image_name))

    while True:
        cv2.imshow(window_name, im_contours)
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('0'):
            break

    cv2.destroyAllWindows()

def select_image_file():
    file_path = filedialog.askopenfilename(filetypes=[("Image files", "*.jpg *.jpeg *.png *.tif *.bmp")])
    if file_path:
        image_path_entry.delete(0, tk.END)
        image_path_entry.insert(0, file_path)

def start_extraction():
    image_path = image_path_entry.get()
    output_dir = single_output_dir.get()
    
    if not image_path or not output_dir:
        messagebox.showerror("Errore", "Seleziona un'immagine e una directory di output.")
        return
    
    detect_characters(image_path, output_dir)
    messagebox.showinfo("Successo", "Estrazione dei caratteri completata.")

def start_batch_processing():
    process_all_images()

# Configurazione dell'interfaccia grafica
root = tk.Tk()
root.title("Strumento di Elaborazione Immagini")
root.geometry("600x300")

def set_mode():
    mode = mode_var.get()
    if mode == 1:
        batch_frame.pack_forget()
        single_frame.pack(pady=10)
    else:
        single_frame.pack_forget()
        batch_frame.pack(pady=10)

mode_var = tk.IntVar(value=1)
tk.Radiobutton(root, text="Elaborazione Singola Immagine", variable=mode_var, value=1, command=set_mode).pack(anchor="w")
tk.Radiobutton(root, text="Elaborazione Batch", variable=mode_var, value=2, command=set_mode).pack(anchor="w")

single_frame = tk.Frame(root)
batch_frame = tk.Frame(root)

tk.Label(single_frame, text="Seleziona l'immagine:").grid(row=0, column=0, padx=10, pady=5)
image_path_entry = tk.Entry(single_frame, width=50)
image_path_entry.grid(row=0, column=1, padx=10, pady=5)
tk.Button(single_frame, text="Sfoglia", command=select_image_file).grid(row=0, column=2, padx=10, pady=5)

tk.Label(single_frame, text="Seleziona la directory di output:").grid(row=1, column=0, padx=10, pady=5)
single_output_dir = tk.StringVar()
output_dir_entry = tk.Entry(single_frame, textvariable=single_output_dir, width=50)
output_dir_entry.grid(row=1, column=1, padx=10, pady=5)
tk.Button(single_frame, text="Sfoglia", command=select_output_directory).grid(row=1, column=2, padx=10, pady=5)

tk.Button(single_frame, text="Avvia estrazione", command=start_extraction).grid(row=2, column=1, padx=10, pady=20)

tk.Label(batch_frame, text="Directory di input:").grid(row=0, column=0, padx=10, pady=5)
input_dir = tk.StringVar()
batch_output_dir = tk.StringVar()
input_entry = tk.Entry(batch_frame, textvariable=input_dir, width=50)
input_entry.grid(row=0, column=1, padx=10, pady=5)
input_button = tk.Button(batch_frame, text="Sfoglia", command=select_input_directory)
input_button.grid(row=0, column=2, padx=10, pady=5)

tk.Label(batch_frame, text="Directory di output:").grid(row=1, column=0, padx=10, pady=5)
output_entry = tk.Entry(batch_frame, textvariable=batch_output_dir, width=50)
output_entry.grid(row=1, column=1, padx=10, pady=5)
output_button = tk.Button(batch_frame, text="Sfoglia", command=select_output_directory)
output_button.grid(row=1, column=2, padx=10, pady=5)

tk.Button(batch_frame, text="Processa tutte le immagini", command=start_batch_processing).grid(row=2, column=1, padx=10, pady=20)

set_mode()
root.mainloop()
# Out:
# Errore durante la lettura dell'immagine: C:/Users/orazi/OneDrive/Desktop/tesi/cvl-database-1-1/testset/words/0363\0363-3-0-0-Mailüfterl.tif
# Errore durante la lettura dell'immagine: C:/Users/orazi/OneDrive/Desktop/tesi/cvl-database-1-1/testset/words/0363\0363-3-10-1-Binär.tif
# Errore durante la lettura dell'immagine: C:/Users/orazi/OneDrive/Desktop/tesi/cvl-database-1-1/testset/words/0363\0363-3-9-3-Mailüfterl.tif
# Errore durante la lettura dell'immagine: C:/Users/orazi/OneDrive/Desktop/tesi/cvl-database-1-1/testset/words/0363\0363-6-1-5-schön.tif
# Errore durante la lettura dell'immagine: C:/Users/orazi/OneDrive/Desktop/tesi/cvl-database-1-1/testset/words/0363\0363-6-7-4-für.tif

# %% [markdown]
# <H1>PER MIGLIORARE LA QUALITà DELL'IMMAGINE</H1>

# %%
contrast_factor = 2.0  
sharpness_factor = 2.0  

def process_image(image_path, output_path):
    try:
        im = Image.open(image_path)
    except Exception as e:
        print(f"Could not read image {image_path}: {e}")
        return
    

    enhancer = ImageEnhance.Contrast(im)
    image_enhanced = enhancer.enhance(contrast_factor)


    sharpener = ImageEnhance.Sharpness(image_enhanced)
    image_sharpened = sharpener.enhance(sharpness_factor)


    image_gray = image_sharpened.convert("L")
    

    image_gray.save(output_path)

def process_directory(input_dir, output_dir):

    for subdir, _, files in os.walk(input_dir):
        for file in files:
         
            file_path = os.path.join(subdir, file)
          
            relative_path = os.path.relpath(file_path, input_dir)
            output_path = os.path.join(output_dir, relative_path)
            
       
            os.makedirs(os.path.dirname(output_path), exist_ok=True)
            
      
            process_image(file_path, output_path)


input_directory = r'C:\Users\orazi\OneDrive\Desktop\tesi\datiT\dati5-1' 
output_directory = r'C:\Users\orazi\OneDrive\Desktop\tesi\datiT\dati5-1' 

process_directory(input_directory, output_directory)

# %% [markdown]
# <H1>PER SALVARE CARTELLA CON IMMAGINI DENTRO</H1>

# %%
def rename_files_with_folder_name(input_folder, output_folder):

    for root, dirs, files in os.walk(input_folder):
        for file in files:

            file_path = os.path.join(root, file)
  
            folder_name = os.path.basename(root)

            new_file_name = f"{folder_name}_{file}"
            

            relative_path = os.path.relpath(root, input_folder)
            new_folder_path = os.path.join(output_folder, relative_path)
            
            if not os.path.exists(new_folder_path):
                os.makedirs(new_folder_path)
                

            new_file_path = os.path.join(new_folder_path, new_file_name)
            

            shutil.copy2(file_path, new_file_path)

input_folder = r"C:\Users\orazi\OneDrive\Desktop\LetterClassifier\toAdd\soggetto34"
output_folder = r"C:\Users\orazi\OneDrive\Desktop\LetterClassifier\toAdd\soggetto34A"

rename_files_with_folder_name(input_folder, output_folder)

# %% [markdown]
# <h1>PER SALVARE LE IMMAGINI IN UNA SINGOLA CARTELLA</h1>

# %%
def rename_files_with_folder_name(input_folder, output_folder):
    # Creare la cartella di output se non esiste
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    

    for root, dirs, files in os.walk(input_folder):
        for file in files:
         
            file_path = os.path.join(root, file)

            folder_name = os.path.basename(root)

            new_file_name = f"{folder_name}_{file}"
            
            new_file_path = os.path.join(output_folder, new_file_name)
         
            shutil.copy2(file_path, new_file_path)

input_folder = r"C:\Users\orazi\OneDrive\Desktop\tesi\soggetti2\0020"
output_folder = r"C:\Users\orazi\OneDrive\Desktop\tesi\soggetti\0024"

rename_files_with_folder_name(input_folder, output_folder)

# %%
import os
from PIL import Image

def resize_images_in_nested_folders(input_folder, output_folder=None, size=(50, 50)):
    if output_folder is None:
        output_folder = input_folder
    
    for root, dirs, files in os.walk(input_folder):
        # Costruire il percorso di output mantenendo la struttura delle cartelle
        relative_path = os.path.relpath(root, input_folder)
        output_dir = os.path.join(output_folder, relative_path)
        
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        
        for filename in files:
            if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
                img_path = os.path.join(root, filename)
                try:
                    img = Image.open(img_path)
                    img = img.resize(size, Image.LANCZOS)
                    output_path = os.path.join(output_dir, filename)
                    img.save(output_path)
                    print(f'Resized and saved {filename} to {output_path}')
                except Exception as e:
                    print(f"Could not process file {filename}: {e}")

input_folder = r'dataset'
output_folder = 'dataset_resized'  # Optional, use None to overwrite input folder

resize_images_in_nested_folders(input_folder, output_folder)
# Out:
# Resized and saved a_0001-1-0-0-Imagine_character_3.png to dataset_resized\soggetto1\a\a_0001-1-0-0-Imagine_character_3.png
# Resized and saved a_0001-1-0-1-a_character_1.png to dataset_resized\soggetto1\a\a_0001-1-0-1-a_character_1.png
# Resized and saved a_0001-1-0-2-vast_character_2.png to dataset_resized\soggetto1\a\a_0001-1-0-2-vast_character_2.png
# Resized and saved a_0001-1-0-5-paper_character_2.png to dataset_resized\soggetto1\a\a_0001-1-0-5-paper_character_2.png
# Resized and saved a_0001-1-0-8-straight_character_4.png to dataset_resized\soggetto1\a\a_0001-1-0-8-straight_character_4.png
# Resized and saved a_0001-1-1-1-Triangles_character_4.png to dataset_resized\soggetto1\a\a_0001-1-1-1-Triangles_character_4.png
# Resized and saved a_0001-1-1-3-Squares_character_4.png to dataset_resized\soggetto1\a\a_0001-1-1-3-Squares_character_4.png
# Resized and saved a_0001-1-1-4-Pentagons_character_6.png to dataset_resized\soggetto1\a\a_0001-1-1-4-Pentagons_character_6.png
# Resized and saved a_0001-1-1-7-and_character_1.png to dataset_resized\soggetto1\a\a_0001-1-1-7-and_character_1.png
# Resized and saved a_0001-1-2-2-instead_character_6.png to dataset_resized\soggetto1\a\a_0001-1-2-2-instead_character_6.png
# Resized and saved a_0001-1-2-8-places_character_3.png to dataset_resized\soggetto1\a\a_0001-1-2-8-places_character_3.png
# Resized and saved a_0001-1-3-2-about_character_1.png to dataset_resized\soggetto1\a\a_0001-1-3-2-about_character_1.png
# Resized and saved a_0001-1-5-3-shadows_character_3.png to dataset_resized\soggetto1\a\a_0001-1-5-3-shadows_character_3.png
# Resized and saved a_0001-1-5-6-hard_character_3.png to dataset_resized\soggetto1\a\a_0001-1-5-6-hard_character_3.png
# Resized and saved a_0001-1-5-7-and_character_1.png to dataset_resized\soggetto1\a\a_0001-1-5-7-and_character_1.png
# Resized and saved a_0001-1-6-0-luminous_character_6.png to dataset_resized\soggetto1\a\a_0001-1-6-0-luminous_character_6.png
# Resized and saved a_0001-1-6-2-and_character_1.png to dataset_resized\soggetto1\a\a_0001-1-6-2-and_character_1.png
# Resized and saved a_0001-1-6-6-have_character_2.png to dataset_resized\soggetto1\a\a_0001-1-6-6-have_character_2.png
# Resized and saved a_0001-1-6-7-a_character_1.png to dataset_resized\soggetto1\a\a_0001-1-6-7-a_character_1.png
# Resized and saved a_0001-1-7-6-and_character_2.png to dataset_resized\soggetto1\a\a_0001-1-7-6-and_character_2.png
# Resized and saved a_0001-1-8-0-Alas_character_1.png to dataset_resized\soggetto1\a\a_0001-1-8-0-Alas_character_1.png
# Resized and saved a_0001-1-8-0-Alas_character_3.png to dataset_resized\soggetto1\a\a_0001-1-8-0-Alas_character_3.png
# Resized and saved a_0001-1-8-1-a_character_1.png to dataset_resized\soggetto1\a\a_0001-1-8-1-a_character_1.png
# Resized and saved a_0001-1-8-3-years_character_3.png to dataset_resized\soggetto1\a\a_0001-1-8-3-years_character_3.png
# Resized and saved a_0001-1-8-4-ago_character_1.png to dataset_resized\soggetto1\a\a_0001-1-8-4-ago_character_1.png
# Resized and saved a_0001-1-8-7-have_character_2.png to dataset_resized\soggetto1\a\a_0001-1-8-7-have_character_2.png
# Resized and saved a_0001-1-8-8-said_character_3.png to dataset_resized\soggetto1\a\a_0001-1-8-8-said_character_3.png
# Resized and saved a_0001-1-9-8-has_character_2.png to dataset_resized\soggetto1\a\a_0001-1-9-8-has_character_2.png
# Resized and saved a_0001-2-0-0-And_character_1.png to dataset_resized\soggetto1\a\a_0001-2-0-0-And_character_1.png
# Resized and saved a_0001-2-0-4-damned_character_2.png to dataset_resized\soggetto1\a\a_0001-2-0-4-damned_character_2.png
# Resized and saved a_0001-2-0-5-quarrel_character_3.png to dataset_resized\soggetto1\a\a_0001-2-0-5-quarrel_character_3.png
# Resized and saved a_0001-2-1-2-a_character_1.png to dataset_resized\soggetto1\a\a_0001-2-1-2-a_character_1.png
# Resized and saved a_0001-2-1-6-all's_character_1.png to dataset_resized\soggetto1\a\a_0001-2-1-6-all's_character_1.png
# Resized and saved a_0001-2-1-8-weak_character_3.png to dataset_resized\soggetto1\a\a_0001-2-1-8-weak_character_3.png
# Resized and saved a_0001-2-2-1-brave_character_3.png to dataset_resized\soggetto1\a\a_0001-2-2-1-brave_character_3.png
# Resized and saved a_0001-2-2-2-Nomacs_character_4.png to dataset_resized\soggetto1\a\a_0001-2-2-2-Nomacs_character_4.png
# Resized and saved a_0001-2-2-7-that_character_3.png to dataset_resized\soggetto1\a\a_0001-2-2-7-that_character_3.png
# Resized and saved a_0001-2-2-8-name_character_2.png to dataset_resized\soggetto1\a\a_0001-2-2-8-name_character_2.png
# Resized and saved a_0001-2-3-0-Disdaining_character_5.png to dataset_resized\soggetto1\a\a_0001-2-3-0-Disdaining_character_5.png
# Resized and saved a_0001-2-3-5-brandish'd_character_3.png to dataset_resized\soggetto1\a\a_0001-2-3-5-brandish'd_character_3.png
# Resized and saved a_0001-2-5-1-valour's_character_2.png to dataset_resized\soggetto1\a\a_0001-2-5-1-valour's_character_2.png
# Resized and saved a_0001-2-5-3-carved_character_2.png to dataset_resized\soggetto1\a\a_0001-2-5-3-carved_character_2.png
# Resized and saved a_0001-2-5-6-passage_character_5.png to dataset_resized\soggetto1\a\a_0001-2-5-6-passage_character_5.png
# Resized and saved a_0001-2-6-2-faced_character_2.png to dataset_resized\soggetto1\a\a_0001-2-6-2-faced_character_2.png
# Resized and saved a_0001-2-6-4-slave_character_3.png to dataset_resized\soggetto1\a\a_0001-2-6-4-slave_character_3.png
# Resized and saved a_0001-3-0-2-an_character_1.png to dataset_resized\soggetto1\a\a_0001-3-0-2-an_character_1.png
# Resized and saved a_0001-3-0-3-Austrian_character_1.png to dataset_resized\soggetto1\a\a_0001-3-0-3-Austrian_character_1.png
# Resized and saved a_0001-3-0-3-Austrian_character_7.png to dataset_resized\soggetto1\a\a_0001-3-0-3-Austrian_character_7.png
# Resized and saved a_0001-3-1-5-transistors_character_3.png to dataset_resized\soggetto1\a\a_0001-3-1-5-transistors_character_3.png
# Resized and saved a_0001-3-2-2-European_character_7.png to dataset_resized\soggetto1\a\a_0001-3-2-2-European_character_7.png
# Resized and saved a_0001-3-2-3-mainland_character_2.png to dataset_resized\soggetto1\a\a_0001-3-2-3-mainland_character_2.png
# Resized and saved a_0001-3-2-3-mainland_character_7.png to dataset_resized\soggetto1\a\a_0001-3-2-3-mainland_character_7.png
# Resized and saved a_0001-3-2-5-was_character_2.png to dataset_resized\soggetto1\a\a_0001-3-2-5-was_character_2.png
# Resized and saved a_0001-3-3-1-at_character_1.png to dataset_resized\soggetto1\a\a_0001-3-3-1-at_character_1.png
# Resized and saved a_0001-3-3-3-Vienna_character_6.png to dataset_resized\soggetto1\a\a_0001-3-3-3-Vienna_character_6.png
# Resized and saved a_0001-3-4-1-Zemanek_character_4.png to dataset_resized\soggetto1\a\a_0001-3-4-1-Zemanek_character_4.png
# Resized and saved a_0001-3-4-4-plays_character_3.png to dataset_resized\soggetto1\a\a_0001-3-4-4-plays_character_3.png
# Resized and saved a_0001-3-5-1-an_character_1.png to dataset_resized\soggetto1\a\a_0001-3-5-1-an_character_1.png
# Resized and saved a_0001-3-5-2-operating_character_5.png to dataset_resized\soggetto1\a\a_0001-3-5-2-operating_character_5.png
# Resized and saved a_0001-3-6-1-rapid_character_2.png to dataset_resized\soggetto1\a\a_0001-3-6-1-rapid_character_2.png
# Resized and saved a_0001-3-6-2-calculation_character_2.png to dataset_resized\soggetto1\a\a_0001-3-6-2-calculation_character_2.png
# Resized and saved a_0001-3-6-2-calculation_character_7.png to dataset_resized\soggetto1\a\a_0001-3-6-2-calculation_character_7.png
# Resized and saved a_0001-3-6-5-American_character_7.png to dataset_resized\soggetto1\a\a_0001-3-6-5-American_character_7.png
# Resized and saved a_0001-3-7-0-that_character_3.png to dataset_resized\soggetto1\a\a_0001-3-7-0-that_character_3.png
# Resized and saved a_0001-3-7-4-can_character_2.png to dataset_resized\soggetto1\a\a_0001-3-7-4-can_character_2.png
# Resized and saved a_0001-3-7-5-achieve_character_1.png to dataset_resized\soggetto1\a\a_0001-3-7-5-achieve_character_1.png
# Resized and saved a_0001-3-8-4-a_character_1.png to dataset_resized\soggetto1\a\a_0001-3-8-4-a_character_1.png
# Resized and saved a_0001-3-9-2-name_character_2.png to dataset_resized\soggetto1\a\a_0001-3-9-2-name_character_2.png
# Resized and saved a_0001-3-9-6-dezimaler_character_7.png to dataset_resized\soggetto1\a\a_0001-3-9-6-dezimaler_character_7.png
# Resized and saved a_0001-4-0-5-individuals_character_9.png to dataset_resized\soggetto1\a\a_0001-4-0-5-individuals_character_9.png
# Resized and saved a_0001-4-1-1-variety_character_2.png to dataset_resized\soggetto1\a\a_0001-4-1-1-variety_character_2.png
# Resized and saved a_0001-4-2-0-cultivated_character_7.png to dataset_resized\soggetto1\a\a_0001-4-2-0-cultivated_character_7.png
# Resized and saved a_0001-4-2-1-plants_character_3.png to dataset_resized\soggetto1\a\a_0001-4-2-1-plants_character_3.png
# Resized and saved a_0001-4-2-3-animals_character_1.png to dataset_resized\soggetto1\a\a_0001-4-2-3-animals_character_1.png
# Resized and saved a_0001-4-2-3-animals_character_5.png to dataset_resized\soggetto1\a\a_0001-4-2-3-animals_character_5.png
# Resized and saved a_0001-4-4-0-generally_character_6.png to dataset_resized\soggetto1\a\a_0001-4-4-0-generally_character_6.png
# Resized and saved a_0001-4-5-3-individuals_character_9.png to dataset_resized\soggetto1\a\a_0001-4-5-3-individuals_character_9.png
# Resized and saved a_0001-4-5-5-any_character_1.png to dataset_resized\soggetto1\a\a_0001-4-5-5-any_character_1.png
# Resized and saved b_0001-1-3-2-about_character_2.png to dataset_resized\soggetto1\b\b_0001-1-3-2-about_character_2.png
# Resized and saved b_0001-1-3-8-but_character_1.png to dataset_resized\soggetto1\b\b_0001-1-3-8-but_character_1.png
# Resized and saved b_0001-1-4-5-above_character_2.png to dataset_resized\soggetto1\b\b_0001-1-4-5-above_character_2.png
# Resized and saved b_0001-1-4-8-below_character_1.png to dataset_resized\soggetto1\b\b_0001-1-4-8-below_character_1.png
# Resized and saved b_0001-1-9-3-but_character_1.png to dataset_resized\soggetto1\b\b_0001-1-9-3-but_character_1.png
# Resized and saved b_0001-1-9-9-been_character_1.png to dataset_resized\soggetto1\b\b_0001-1-9-9-been_character_1.png
# Resized and saved b_0001-2-1-3-rebel's_character_3.png to dataset_resized\soggetto1\b\b_0001-2-1-3-rebel's_character_3.png
# Resized and saved b_0001-2-1-5-but_character_1.png to dataset_resized\soggetto1\b\b_0001-2-1-5-but_character_1.png
# Resized and saved b_0001-2-2-1-brave_character_1.png to dataset_resized\soggetto1\b\b_0001-2-2-1-brave_character_1.png
# Resized and saved b_0001-2-3-5-brandish'd_character_1.png to dataset_resized\soggetto1\b\b_0001-2-3-5-brandish'd_character_1.png
# Resized and saved b_0001-2-4-3-bloody_character_1.png to dataset_resized\soggetto1\b\b_0001-2-4-3-bloody_character_1.png
# Resized and saved b_0001-3-2-6-built_character_1.png to dataset_resized\soggetto1\b\b_0001-3-2-6-built_character_1.png
# Resized and saved b_0001-3-3-7-by_character_1.png to dataset_resized\soggetto1\b\b_0001-3-3-7-by_character_1.png
# Resized and saved b_0001-3-4-3-builder_character_1.png to dataset_resized\soggetto1\b\b_0001-3-4-3-builder_character_1.png
# Resized and saved b_0001-3-8-1-be_character_1.png to dataset_resized\soggetto1\b\b_0001-3-8-1-be_character_1.png
# Resized and saved b_0001-4-1-3-sub-variety_character_1.png to dataset_resized\soggetto1\b\b_0001-4-1-3-sub-variety_character_1.png
# Resized and saved b_0001-6-1-3-bist_character_1.png to dataset_resized\soggetto1\b\b_0001-6-1-3-bist_character_1.png
# Resized and saved b_0001-6-3-6-Grunde_character_1.png to dataset_resized\soggetto1\b\b_0001-6-3-6-Grunde_character_1.png
# Resized and saved b_0001-6-5-1-bist_character_1.png to dataset_resized\soggetto1\b\b_0001-6-5-1-bist_character_1.png
# Resized and saved b_0001-6-7-6-vorbey_character_1.png to dataset_resized\soggetto1\b\b_0001-6-7-6-vorbey_character_1.png
# Resized and saved b_0001-7-3-3-because_character_1.png to dataset_resized\soggetto1\b\b_0001-7-3-3-because_character_1.png
# Resized and saved b_0001-7-4-0-because_character_1.png to dataset_resized\soggetto1\b\b_0001-7-4-0-because_character_1.png
# Resized and saved b_0001-7-5-0-because_character_1.png to dataset_resized\soggetto1\b\b_0001-7-5-0-because_character_1.png
# Resized and saved b_0001-7-6-5-substance_character_1.png to dataset_resized\soggetto1\b\b_0001-7-6-5-substance_character_1.png
# Resized and saved b_0001-8-1-6-breath_character_1.png to dataset_resized\soggetto1\b\b_0001-8-1-6-breath_character_1.png
# Resized and saved b_0001-8-2-5-orb_character_1.png to dataset_resized\soggetto1\b\b_0001-8-2-5-orb_character_1.png
# Resized and saved b_0001-8-3-1-burst_character_1.png to dataset_resized\soggetto1\b\b_0001-8-3-1-burst_character_1.png
# Resized and saved b_0001-8-4-1-brain_character_1.png to dataset_resized\soggetto1\b\b_0001-8-4-1-brain_character_1.png
# Resized and saved c_0001-1-0-7-which_character_4.png to dataset_resized\soggetto1\c\c_0001-1-0-7-which_character_4.png
# Resized and saved c_0001-1-2-8-places_character_4.png to dataset_resized\soggetto1\c\c_0001-1-2-8-places_character_4.png
# Resized and saved c_0001-1-3-7-surface_character_6.png to dataset_resized\soggetto1\c\c_0001-1-3-7-surface_character_6.png
# Resized and saved c_0001-1-5-1-much_character_3.png to dataset_resized\soggetto1\c\c_0001-1-5-1-much_character_3.png
# Resized and saved c_0001-1-7-1-correct_character_1.png to dataset_resized\soggetto1\c\c_0001-1-7-1-correct_character_1.png
# Resized and saved c_0001-1-7-1-correct_character_5.png to dataset_resized\soggetto1\c\c_0001-1-7-1-correct_character_5.png
# Resized and saved c_0001-1-7-1-correct_character_6.png to dataset_resized\soggetto1\c\c_0001-1-7-1-correct_character_6.png
# Resized and saved c_0001-1-7-5-country_character_1.png to dataset_resized\soggetto1\c\c_0001-1-7-5-country_character_1.png
# Resized and saved c_0001-1-7-7-countrymen_character_1.png to dataset_resized\soggetto1\c\c_0001-1-7-7-countrymen_character_1.png
# Resized and saved c_0001-2-2-2-Nomacs_character_5.png to dataset_resized\soggetto1\c\c_0001-2-2-2-Nomacs_character_5.png
# Resized and saved c_0001-2-2-2-Nomacs_character_6.png to dataset_resized\soggetto1\c\c_0001-2-2-2-Nomacs_character_6.png
# Resized and saved c_0001-2-4-0-Which_character_4.png to dataset_resized\soggetto1\c\c_0001-2-4-0-Which_character_4.png
# Resized and saved c_0001-2-4-4-execution_character_4.png to dataset_resized\soggetto1\c\c_0001-2-4-4-execution_character_4.png
# Resized and saved c_0001-2-5-3-carved_character_1.png to dataset_resized\soggetto1\c\c_0001-2-5-3-carved_character_1.png
# Resized and saved c_0001-3-1-1-computer_character_1.png to dataset_resized\soggetto1\c\c_0001-3-1-1-computer_character_1.png
# Resized and saved c_0001-3-3-6-Technology_character_12.png to dataset_resized\soggetto1\c\c_0001-3-3-6-Technology_character_12.png
# Resized and saved c_0001-3-5-3-computer_character_1.png to dataset_resized\soggetto1\c\c_0001-3-5-3-computer_character_1.png
# Resized and saved c_0001-3-6-2-calculation_character_1.png to dataset_resized\soggetto1\c\c_0001-3-6-2-calculation_character_1.png
# Resized and saved c_0001-3-6-2-calculation_character_4.png to dataset_resized\soggetto1\c\c_0001-3-6-2-calculation_character_4.png
# Resized and saved c_0001-3-7-4-can_character_1.png to dataset_resized\soggetto1\c\c_0001-3-7-4-can_character_1.png
# Resized and saved c_0001-3-7-5-achieve_character_2.png to dataset_resized\soggetto1\c\c_0001-3-7-5-achieve_character_2.png
# Resized and saved c_0001-4-2-0-cultivated_character_1.png to dataset_resized\soggetto1\c\c_0001-4-2-0-cultivated_character_1.png
# Resized and saved d_0001-1-1-7-and_character_3.png to dataset_resized\soggetto1\d\d_0001-1-1-7-and_character_3.png
# Resized and saved d_0001-1-10-0-opened_character_7.png to dataset_resized\soggetto1\d\d_0001-1-10-0-opened_character_7.png
# Resized and saved d_0001-1-2-2-instead_character_7.png to dataset_resized\soggetto1\d\d_0001-1-2-2-instead_character_7.png
# Resized and saved d_0001-1-2-5-fixed_character_5.png to dataset_resized\soggetto1\d\d_0001-1-2-5-fixed_character_5.png
# Resized and saved d_0001-1-5-3-shadows_character_4.png to dataset_resized\soggetto1\d\d_0001-1-5-3-shadows_character_4.png
# Resized and saved d_0001-1-5-6-hard_character_2.png to dataset_resized\soggetto1\d\d_0001-1-5-6-hard_character_2.png
# Resized and saved d_0001-1-5-7-and_character_3.png to dataset_resized\soggetto1\d\d_0001-1-5-7-and_character_3.png
# Resized and saved d_0001-1-6-1-edges_character_2.png to dataset_resized\soggetto1\d\d_0001-1-6-1-edges_character_2.png
# Resized and saved d_0001-1-6-2-and_character_3.png to dataset_resized\soggetto1\d\d_0001-1-6-2-and_character_3.png
# Resized and saved d_0001-1-7-6-and_character_4.png to dataset_resized\soggetto1\d\d_0001-1-7-6-and_character_4.png
# Resized and saved d_0001-1-8-6-should_character_6.png to dataset_resized\soggetto1\d\d_0001-1-8-6-should_character_6.png
# Resized and saved d_0001-1-8-8-said_character_5.png to dataset_resized\soggetto1\d\d_0001-1-8-8-said_character_5.png
# Resized and saved d_0001-1-9-6-mind_character_4.png to dataset_resized\soggetto1\d\d_0001-1-9-6-mind_character_4.png
# Resized and saved d_0001-2-0-0-And_character_3.png to dataset_resized\soggetto1\d\d_0001-2-0-0-And_character_3.png
# Resized and saved d_0001-2-0-4-damned_character_1.png to dataset_resized\soggetto1\d\d_0001-2-0-4-damned_character_1.png
# Resized and saved d_0001-2-0-4-damned_character_6.png to dataset_resized\soggetto1\d\d_0001-2-0-4-damned_character_6.png
# Resized and saved d_0001-2-1-0-Show'd_character_5.png to dataset_resized\soggetto1\d\d_0001-2-1-0-Show'd_character_5.png
# Resized and saved d_0001-2-2-6-deserves_character_1.png to dataset_resized\soggetto1\d\d_0001-2-2-6-deserves_character_1.png
# Resized and saved d_0001-2-3-0-Disdaining_character_1.png to dataset_resized\soggetto1\d\d_0001-2-3-0-Disdaining_character_1.png
# Resized and saved d_0001-2-3-0-Disdaining_character_4.png to dataset_resized\soggetto1\d\d_0001-2-3-0-Disdaining_character_4.png
# Resized and saved d_0001-2-3-5-brandish'd_character_5.png to dataset_resized\soggetto1\d\d_0001-2-3-5-brandish'd_character_5.png
# Resized and saved d_0001-2-3-5-brandish'd_character_9.png to dataset_resized\soggetto1\d\d_0001-2-3-5-brandish'd_character_9.png
# Resized and saved d_0001-2-4-1-smoked_character_6.png to dataset_resized\soggetto1\d\d_0001-2-4-1-smoked_character_6.png
# Resized and saved d_0001-2-4-3-bloody_character_5.png to dataset_resized\soggetto1\d\d_0001-2-4-3-bloody_character_5.png
# Resized and saved d_0001-2-5-3-carved_character_6.png to dataset_resized\soggetto1\d\d_0001-2-5-3-carved_character_6.png
# Resized and saved d_0001-2-6-2-faced_character_5.png to dataset_resized\soggetto1\d\d_0001-2-6-2-faced_character_5.png
# Resized and saved d_0001-3-2-3-mainland_character_9.png to dataset_resized\soggetto1\d\d_0001-3-2-3-mainland_character_9.png
# Resized and saved d_0001-3-6-1-rapid_character_5.png to dataset_resized\soggetto1\d\d_0001-3-6-1-rapid_character_5.png
# Resized and saved d_0001-3-6-3-speed_character_5.png to dataset_resized\soggetto1\d\d_0001-3-6-3-speed_character_5.png
# Resized and saved d_0001-3-6-6-models_character_3.png to dataset_resized\soggetto1\d\d_0001-3-6-6-models_character_3.png
# Resized and saved d_0001-3-7-1-Whirlwind_character_9.png to dataset_resized\soggetto1\d\d_0001-3-7-1-Whirlwind_character_9.png
# Resized and saved d_0001-3-9-6-dezimaler_character_2.png to dataset_resized\soggetto1\d\d_0001-3-9-6-dezimaler_character_2.png
# Resized and saved d_0001-4-0-5-individuals_character_3.png to dataset_resized\soggetto1\d\d_0001-4-0-5-individuals_character_3.png
# Resized and saved d_0001-4-0-5-individuals_character_7.png to dataset_resized\soggetto1\d\d_0001-4-0-5-individuals_character_7.png
# Resized and saved d_0001-4-2-0-cultivated_character_10.png to dataset_resized\soggetto1\d\d_0001-4-2-0-cultivated_character_10.png
# Resized and saved d_0001-4-5-3-individuals_character_3.png to dataset_resized\soggetto1\d\d_0001-4-5-3-individuals_character_3.png
# Resized and saved d_0001-4-5-3-individuals_character_7.png to dataset_resized\soggetto1\d\d_0001-4-5-3-individuals_character_7.png
# Resized and saved e_0001-1-0-0-Imagine_character_2.png to dataset_resized\soggetto1\e\e_0001-1-0-0-Imagine_character_2.png
# Resized and saved e_0001-1-0-3-sheet_character_3.png to dataset_resized\soggetto1\e\e_0001-1-0-3-sheet_character_3.png
# Resized and saved e_0001-1-0-3-sheet_character_4.png to dataset_resized\soggetto1\e\e_0001-1-0-3-sheet_character_4.png
# Resized and saved e_0001-1-0-5-paper_character_4.png to dataset_resized\soggetto1\e\e_0001-1-0-5-paper_character_4.png
# Resized and saved e_0001-1-1-0-Lines_character_5.png to dataset_resized\soggetto1\e\e_0001-1-1-0-Lines_character_5.png
# Resized and saved e_0001-1-1-1-Triangles_character_8.png to dataset_resized\soggetto1\e\e_0001-1-1-1-Triangles_character_8.png
# Resized and saved e_0001-1-1-3-Squares_character_6.png to dataset_resized\soggetto1\e\e_0001-1-1-3-Squares_character_6.png
# Resized and saved e_0001-1-1-4-Pentagons_character_3.png to dataset_resized\soggetto1\e\e_0001-1-1-4-Pentagons_character_3.png
# Resized and saved e_0001-1-1-6-Hexagons_character_2.png to dataset_resized\soggetto1\e\e_0001-1-1-6-Hexagons_character_2.png
# Resized and saved e_0001-1-1-6-Hexagons_character_4.png to dataset_resized\soggetto1\e\e_0001-1-1-6-Hexagons_character_4.png
# Resized and saved e_0001-1-10-0-opened_character_3.png to dataset_resized\soggetto1\e\e_0001-1-10-0-opened_character_3.png
# Resized and saved e_0001-1-10-0-opened_character_5.png to dataset_resized\soggetto1\e\e_0001-1-10-0-opened_character_5.png
# Resized and saved e_0001-1-10-3-views_character_3.png to dataset_resized\soggetto1\e\e_0001-1-10-3-views_character_3.png
# Resized and saved e_0001-1-2-0-figures_character_6.png to dataset_resized\soggetto1\e\e_0001-1-2-0-figures_character_6.png
# Resized and saved e_0001-1-2-2-instead_character_5.png to dataset_resized\soggetto1\e\e_0001-1-2-2-instead_character_5.png
# Resized and saved e_0001-1-2-7-their_character_3.png to dataset_resized\soggetto1\e\e_0001-1-2-7-their_character_3.png
# Resized and saved e_0001-1-2-8-places_character_5.png to dataset_resized\soggetto1\e\e_0001-1-2-8-places_character_5.png
# Resized and saved e_0001-1-3-0-move_character_4.png to dataset_resized\soggetto1\e\e_0001-1-3-0-move_character_4.png
# Resized and saved e_0001-1-3-1-freely_character_3.png to dataset_resized\soggetto1\e\e_0001-1-3-1-freely_character_3.png
# Resized and saved e_0001-1-3-1-freely_character_4.png to dataset_resized\soggetto1\e\e_0001-1-3-1-freely_character_4.png
# Resized and saved e_0001-1-3-6-the_character_3.png to dataset_resized\soggetto1\e\e_0001-1-3-6-the_character_3.png
# Resized and saved e_0001-1-3-7-surface_character_5.png to dataset_resized\soggetto1\e\e_0001-1-3-7-surface_character_5.png
# Resized and saved e_0001-1-3-7-surface_character_7.png to dataset_resized\soggetto1\e\e_0001-1-3-7-surface_character_7.png
# Resized and saved e_0001-1-4-0-the_character_3.png to dataset_resized\soggetto1\e\e_0001-1-4-0-the_character_3.png
# Resized and saved e_0001-1-4-1-power_character_5.png to dataset_resized\soggetto1\e\e_0001-1-4-1-power_character_5.png
# Resized and saved e_0001-1-4-5-above_character_5.png to dataset_resized\soggetto1\e\e_0001-1-4-5-above_character_5.png
# Resized and saved e_0001-1-4-8-below_character_2.png to dataset_resized\soggetto1\e\e_0001-1-4-8-below_character_2.png
# Resized and saved e_0001-1-5-0-very_character_2.png to dataset_resized\soggetto1\e\e_0001-1-5-0-very_character_2.png
# Resized and saved e_0001-1-5-2-like_character_4.png to dataset_resized\soggetto1\e\e_0001-1-5-2-like_character_4.png
# Resized and saved e_0001-1-6-1-edges_character_1.png to dataset_resized\soggetto1\e\e_0001-1-6-1-edges_character_1.png
# Resized and saved e_0001-1-6-1-edges_character_4.png to dataset_resized\soggetto1\e\e_0001-1-6-1-edges_character_4.png
# Resized and saved e_0001-1-6-5-then_character_3.png to dataset_resized\soggetto1\e\e_0001-1-6-5-then_character_3.png
# Resized and saved e_0001-1-6-6-have_character_4.png to dataset_resized\soggetto1\e\e_0001-1-6-6-have_character_4.png
# Resized and saved e_0001-1-7-0-pretty_character_3.png to dataset_resized\soggetto1\e\e_0001-1-7-0-pretty_character_3.png
# Resized and saved e_0001-1-7-7-countrymen_character_9.png to dataset_resized\soggetto1\e\e_0001-1-7-7-countrymen_character_9.png
# Resized and saved e_0001-1-8-2-few_character_2.png to dataset_resized\soggetto1\e\e_0001-1-8-2-few_character_2.png
# Resized and saved e_0001-1-8-3-years_character_2.png to dataset_resized\soggetto1\e\e_0001-1-8-3-years_character_2.png
# Resized and saved e_0001-1-8-7-have_character_4.png to dataset_resized\soggetto1\e\e_0001-1-8-7-have_character_4.png
# Resized and saved e_0001-1-9-1-universe_character_5.png to dataset_resized\soggetto1\e\e_0001-1-9-1-universe_character_5.png
# Resized and saved e_0001-1-9-9-been_character_2.png to dataset_resized\soggetto1\e\e_0001-1-9-9-been_character_2.png
# Resized and saved e_0001-1-9-9-been_character_3.png to dataset_resized\soggetto1\e\e_0001-1-9-9-been_character_3.png
# Resized and saved e_0001-2-0-5-quarrel_character_6.png to dataset_resized\soggetto1\e\e_0001-2-0-5-quarrel_character_6.png
# Resized and saved e_0001-2-1-1-like_character_4.png to dataset_resized\soggetto1\e\e_0001-2-1-1-like_character_4.png
# Resized and saved e_0001-2-1-3-rebel's_character_2.png to dataset_resized\soggetto1\e\e_0001-2-1-3-rebel's_character_2.png
# Resized and saved e_0001-2-1-3-rebel's_character_4.png to dataset_resized\soggetto1\e\e_0001-2-1-3-rebel's_character_4.png
# Resized and saved e_0001-2-1-4-whore_character_5.png to dataset_resized\soggetto1\e\e_0001-2-1-4-whore_character_5.png
# Resized and saved e_0001-2-2-4-well_character_2.png to dataset_resized\soggetto1\e\e_0001-2-2-4-well_character_2.png
# Resized and saved e_0001-2-2-6-deserves_character_2.png to dataset_resized\soggetto1\e\e_0001-2-2-6-deserves_character_2.png
# Resized and saved e_0001-2-2-6-deserves_character_4.png to dataset_resized\soggetto1\e\e_0001-2-2-6-deserves_character_4.png
# Resized and saved e_0001-2-2-8-name_character_4.png to dataset_resized\soggetto1\e\e_0001-2-2-8-name_character_4.png
# Resized and saved e_0001-2-3-1-fortune_character_7.png to dataset_resized\soggetto1\e\e_0001-2-3-1-fortune_character_7.png
# Resized and saved e_0001-2-3-6-steel_character_3.png to dataset_resized\soggetto1\e\e_0001-2-3-6-steel_character_3.png
# Resized and saved e_0001-2-3-6-steel_character_4.png to dataset_resized\soggetto1\e\e_0001-2-3-6-steel_character_4.png
# Resized and saved e_0001-2-4-1-smoked_character_5.png to dataset_resized\soggetto1\e\e_0001-2-4-1-smoked_character_5.png
# Resized and saved e_0001-2-4-4-execution_character_1.png to dataset_resized\soggetto1\e\e_0001-2-4-4-execution_character_1.png
# Resized and saved e_0001-2-4-4-execution_character_3.png to dataset_resized\soggetto1\e\e_0001-2-4-4-execution_character_3.png
# Resized and saved e_0001-2-5-0-Like_character_4.png to dataset_resized\soggetto1\e\e_0001-2-5-0-Like_character_4.png
# Resized and saved e_0001-2-6-1-he_character_2.png to dataset_resized\soggetto1\e\e_0001-2-6-1-he_character_2.png
# Resized and saved e_0001-2-6-2-faced_character_4.png to dataset_resized\soggetto1\e\e_0001-2-6-2-faced_character_4.png
# Resized and saved e_0001-2-6-3-the_character_3.png to dataset_resized\soggetto1\e\e_0001-2-6-3-the_character_3.png
# Resized and saved e_0001-2-6-4-slave_character_5.png to dataset_resized\soggetto1\e\e_0001-2-6-4-slave_character_5.png
# Resized and saved e_0001-3-0-4-nickname_character_8.png to dataset_resized\soggetto1\e\e_0001-3-0-4-nickname_character_8.png
# Resized and saved e_0001-3-0-6-the_character_3.png to dataset_resized\soggetto1\e\e_0001-3-0-6-the_character_3.png
# Resized and saved e_0001-3-1-3-solely_character_4.png to dataset_resized\soggetto1\e\e_0001-3-1-3-solely_character_4.png
# Resized and saved e_0001-3-2-1-the_character_3.png to dataset_resized\soggetto1\e\e_0001-3-2-1-the_character_3.png
# Resized and saved e_0001-3-2-2-European_character_6.png to dataset_resized\soggetto1\e\e_0001-3-2-2-European_character_6.png
# Resized and saved e_0001-3-3-2-the_character_3.png to dataset_resized\soggetto1\e\e_0001-3-3-2-the_character_3.png
# Resized and saved e_0001-3-3-3-Vienna_character_3.png to dataset_resized\soggetto1\e\e_0001-3-3-3-Vienna_character_3.png
# Resized and saved e_0001-3-3-4-University_character_5.png to dataset_resized\soggetto1\e\e_0001-3-3-4-University_character_5.png
# Resized and saved e_0001-3-3-6-Technology_character_2.png to dataset_resized\soggetto1\e\e_0001-3-3-6-Technology_character_2.png
# Resized and saved e_0001-3-4-0-Heinz_character_2.png to dataset_resized\soggetto1\e\e_0001-3-4-0-Heinz_character_2.png
# Resized and saved e_0001-3-4-1-Zemanek_character_2.png to dataset_resized\soggetto1\e\e_0001-3-4-1-Zemanek_character_2.png
# Resized and saved e_0001-3-4-1-Zemanek_character_6.png to dataset_resized\soggetto1\e\e_0001-3-4-1-Zemanek_character_6.png
# Resized and saved e_0001-3-4-2-The_character_3.png to dataset_resized\soggetto1\e\e_0001-3-4-2-The_character_3.png
# Resized and saved e_0001-3-5-2-operating_character_3.png to dataset_resized\soggetto1\e\e_0001-3-5-2-operating_character_3.png
# Resized and saved e_0001-3-6-0-the_character_3.png to dataset_resized\soggetto1\e\e_0001-3-6-0-the_character_3.png
# Resized and saved e_0001-3-6-3-speed_character_3.png to dataset_resized\soggetto1\e\e_0001-3-6-3-speed_character_3.png
# Resized and saved e_0001-3-6-3-speed_character_4.png to dataset_resized\soggetto1\e\e_0001-3-6-3-speed_character_4.png
# Resized and saved e_0001-3-6-5-American_character_3.png to dataset_resized\soggetto1\e\e_0001-3-6-5-American_character_3.png
# Resized and saved e_0001-3-6-6-models_character_4.png to dataset_resized\soggetto1\e\e_0001-3-6-6-models_character_4.png
# Resized and saved e_0001-3-7-5-achieve_character_5.png to dataset_resized\soggetto1\e\e_0001-3-7-5-achieve_character_5.png
# Resized and saved e_0001-3-8-2-enough_character_1.png to dataset_resized\soggetto1\e\e_0001-3-8-2-enough_character_1.png
# Resized and saved e_0001-3-8-5-Wiener_character_5.png to dataset_resized\soggetto1\e\e_0001-3-8-5-Wiener_character_5.png
# Resized and saved e_0001-3-9-0-The_character_3.png to dataset_resized\soggetto1\e\e_0001-3-9-0-The_character_3.png
# Resized and saved e_0001-3-9-2-name_character_5.png to dataset_resized\soggetto1\e\e_0001-3-9-2-name_character_5.png
# Resized and saved e_0001-3-9-6-dezimaler_character_3.png to dataset_resized\soggetto1\e\e_0001-3-9-6-dezimaler_character_3.png
# Resized and saved e_0001-4-1-1-variety_character_5.png to dataset_resized\soggetto1\e\e_0001-4-1-1-variety_character_5.png
# Resized and saved e_0001-4-2-0-cultivated_character_9.png to dataset_resized\soggetto1\e\e_0001-4-2-0-cultivated_character_9.png
# Resized and saved e_0001-4-4-0-generally_character_2.png to dataset_resized\soggetto1\e\e_0001-4-4-0-generally_character_2.png
# Resized and saved e_0001-4-4-0-generally_character_4.png to dataset_resized\soggetto1\e\e_0001-4-4-0-generally_character_4.png
# Resized and saved e_0001-6-2-5-Fesseln_character_4.png to dataset_resized\soggetto1\e\e_0001-6-2-5-Fesseln_character_4.png
# Resized and saved f_0001-1-0-4-of_character_2.png to dataset_resized\soggetto1\f\f_0001-1-0-4-of_character_2.png
# Resized and saved f_0001-1-10-4-of_character_2.png to dataset_resized\soggetto1\f\f_0001-1-10-4-of_character_2.png
# Resized and saved f_0001-1-2-0-figures_character_1.png to dataset_resized\soggetto1\f\f_0001-1-2-0-figures_character_1.png
# Resized and saved f_0001-1-2-3-of_character_2.png to dataset_resized\soggetto1\f\f_0001-1-2-3-of_character_2.png
# Resized and saved f_0001-1-2-5-fixed_character_1.png to dataset_resized\soggetto1\f\f_0001-1-2-5-fixed_character_1.png
# Resized and saved f_0001-1-3-1-freely_character_1.png to dataset_resized\soggetto1\f\f_0001-1-3-1-freely_character_1.png
# Resized and saved f_0001-1-3-7-surface_character_4.png to dataset_resized\soggetto1\f\f_0001-1-3-7-surface_character_4.png
# Resized and saved f_0001-1-4-2-of_character_2.png to dataset_resized\soggetto1\f\f_0001-1-4-2-of_character_2.png
# Resized and saved f_0001-1-7-3-of_character_2.png to dataset_resized\soggetto1\f\f_0001-1-7-3-of_character_2.png
# Resized and saved f_0001-1-8-2-few_character_1.png to dataset_resized\soggetto1\f\f_0001-1-8-2-few_character_1.png
# Resized and saved f_0001-2-0-1-fortune_character_1.png to dataset_resized\soggetto1\f\f_0001-2-0-1-fortune_character_1.png
# Resized and saved f_0001-2-2-0-For_character_1.png to dataset_resized\soggetto1\f\f_0001-2-2-0-For_character_1.png
# Resized and saved f_0001-2-3-1-fortune_character_1.png to dataset_resized\soggetto1\f\f_0001-2-3-1-fortune_character_1.png
# Resized and saved f_0001-2-6-2-faced_character_1.png to dataset_resized\soggetto1\f\f_0001-2-6-2-faced_character_1.png
# Resized and saved f_0001-3-0-5-for_character_1.png to dataset_resized\soggetto1\f\f_0001-3-0-5-for_character_1.png
# Resized and saved f_0001-3-1-0-first_character_1.png to dataset_resized\soggetto1\f\f_0001-3-1-0-first_character_1.png
# Resized and saved f_0001-3-5-4-If_character_2.png to dataset_resized\soggetto1\f\f_0001-3-5-4-If_character_2.png
# Resized and saved f_0001-3-8-3-for_character_1.png to dataset_resized\soggetto1\f\f_0001-3-8-3-for_character_1.png
# Resized and saved f_0001-4-4-4-from_character_1.png to dataset_resized\soggetto1\f\f_0001-4-4-4-from_character_1.png
# Resized and saved f_0001-6-2-5-Fesseln_character_3.png to dataset_resized\soggetto1\f\f_0001-6-2-5-Fesseln_character_3.png
# Resized and saved g_0001-1-0-0-Imagine_character_4.png to dataset_resized\soggetto1\g\g_0001-1-0-0-Imagine_character_4.png
# Resized and saved g_0001-1-0-8-straight_character_6.png to dataset_resized\soggetto1\g\g_0001-1-0-8-straight_character_6.png
# Resized and saved g_0001-1-1-1-Triangles_character_6.png to dataset_resized\soggetto1\g\g_0001-1-1-1-Triangles_character_6.png
# Resized and saved g_0001-1-1-4-Pentagons_character_7.png to dataset_resized\soggetto1\g\g_0001-1-1-4-Pentagons_character_7.png
# Resized and saved g_0001-1-1-6-Hexagons_character_5.png to dataset_resized\soggetto1\g\g_0001-1-1-6-Hexagons_character_5.png
# Resized and saved g_0001-1-10-2-higher_character_3.png to dataset_resized\soggetto1\g\g_0001-1-10-2-higher_character_3.png
# Resized and saved g_0001-1-10-5-things_character_5.png to dataset_resized\soggetto1\g\g_0001-1-10-5-things_character_5.png
# Resized and saved g_0001-1-2-0-figures_character_3.png to dataset_resized\soggetto1\g\g_0001-1-2-0-figures_character_3.png
# Resized and saved g_0001-1-2-4-remaining_character_5.png to dataset_resized\soggetto1\g\g_0001-1-2-4-remaining_character_5.png
# Resized and saved g_0001-1-4-4-rising_character_6.png to dataset_resized\soggetto1\g\g_0001-1-4-4-rising_character_6.png
# Resized and saved g_0001-1-4-7-sinking_character_7.png to dataset_resized\soggetto1\g\g_0001-1-4-7-sinking_character_7.png
# Resized and saved g_0001-1-6-1-edges_character_3.png to dataset_resized\soggetto1\g\g_0001-1-6-1-edges_character_3.png
# Resized and saved g_0001-1-8-4-ago_character_2.png to dataset_resized\soggetto1\g\g_0001-1-8-4-ago_character_2.png
# Resized and saved g_0001-2-0-6-smiling_character_8.png to dataset_resized\soggetto1\g\g_0001-2-0-6-smiling_character_8.png
# Resized and saved g_0001-2-3-0-Disdaining_character_10.png to dataset_resized\soggetto1\g\g_0001-2-3-0-Disdaining_character_10.png
# Resized and saved g_0001-2-5-6-passage_character_6.png to dataset_resized\soggetto1\g\g_0001-2-5-6-passage_character_6.png
# Resized and saved g_0001-3-1-2-working_character_7.png to dataset_resized\soggetto1\g\g_0001-3-1-2-working_character_7.png
# Resized and saved g_0001-3-3-6-Technology_character_8.png to dataset_resized\soggetto1\g\g_0001-3-3-6-Technology_character_8.png
# Resized and saved g_0001-3-5-2-operating_character_1.png to dataset_resized\soggetto1\g\g_0001-3-5-2-operating_character_1.png
# Resized and saved g_0001-3-5-2-operating_character_9.png to dataset_resized\soggetto1\g\g_0001-3-5-2-operating_character_9.png
# Resized and saved g_0001-3-8-2-enough_character_1.png to dataset_resized\soggetto1\g\g_0001-3-8-2-enough_character_1.png
# Resized and saved g_0001-3-8-2-enough_character_5.png to dataset_resized\soggetto1\g\g_0001-3-8-2-enough_character_5.png
# Resized and saved g_0001-4-4-0-generally_character_1.png to dataset_resized\soggetto1\g\g_0001-4-4-0-generally_character_1.png
# Resized and saved g_0001-6-2-1-magst_character_1.png to dataset_resized\soggetto1\g\g_0001-6-2-1-magst_character_1.png
# Resized and saved g_0001-6-2-6-schlagen_character_2.png to dataset_resized\soggetto1\g\g_0001-6-2-6-schlagen_character_2.png
# Resized and saved g_0001-6-3-3-gern_character_1.png to dataset_resized\soggetto1\g\g_0001-6-3-3-gern_character_1.png
# Resized and saved g_0001-6-3-7-gehn_character_1.png to dataset_resized\soggetto1\g\g_0001-6-3-7-gehn_character_1.png
# Resized and saved g_0001-6-6-2-mag_character_1.png to dataset_resized\soggetto1\g\g_0001-6-6-2-mag_character_1.png
# Resized and saved g_0001-6-6-5-Zeiger_character_1.png to dataset_resized\soggetto1\g\g_0001-6-6-5-Zeiger_character_1.png
# Resized and saved g_0001-7-1-1-imagination_character_1.png to dataset_resized\soggetto1\g\g_0001-7-1-1-imagination_character_1.png
# Resized and saved g_0001-7-4-3-genius_character_1.png to dataset_resized\soggetto1\g\g_0001-7-4-3-genius_character_1.png
# Resized and saved g_0001-7-5-6-great_character_1.png to dataset_resized\soggetto1\g\g_0001-7-5-6-great_character_1.png
# Resized and saved g_0001-7-6-2-gave_character_1.png to dataset_resized\soggetto1\g\g_0001-7-6-2-gave_character_1.png
# Resized and saved g_0001-8-0-2-gazed_character_1.png to dataset_resized\soggetto1\g\g_0001-8-0-2-gazed_character_1.png
# Resized and saved g_0001-8-5-7-long_character_1.png to dataset_resized\soggetto1\g\g_0001-8-5-7-long_character_1.png
# Resized and saved g_0001-8-6-1-shouting_character_1.png to dataset_resized\soggetto1\g\g_0001-8-6-1-shouting_character_1.png
# Resized and saved g_0001-8-9-4-fragments_character_1.png to dataset_resized\soggetto1\g\g_0001-8-9-4-fragments_character_1.png
# Resized and saved h_0001-1-0-3-sheet_character_2.png to dataset_resized\soggetto1\h\h_0001-1-0-3-sheet_character_2.png
# Resized and saved h_0001-1-0-7-which_character_2.png to dataset_resized\soggetto1\h\h_0001-1-0-7-which_character_2.png
# Resized and saved h_0001-1-0-7-which_character_5.png to dataset_resized\soggetto1\h\h_0001-1-0-7-which_character_5.png
# Resized and saved h_0001-1-0-8-straight_character_7.png to dataset_resized\soggetto1\h\h_0001-1-0-8-straight_character_7.png
# Resized and saved h_0001-1-1-6-Hexagons_character_1.png to dataset_resized\soggetto1\h\h_0001-1-1-6-Hexagons_character_1.png
# Resized and saved h_0001-1-1-8-other_character_3.png to dataset_resized\soggetto1\h\h_0001-1-1-8-other_character_3.png
# Resized and saved h_0001-1-10-2-higher_character_1.png to dataset_resized\soggetto1\h\h_0001-1-10-2-higher_character_1.png
# Resized and saved h_0001-1-10-5-things_character_2.png to dataset_resized\soggetto1\h\h_0001-1-10-5-things_character_2.png
# Resized and saved h_0001-1-2-7-their_character_2.png to dataset_resized\soggetto1\h\h_0001-1-2-7-their_character_2.png
# Resized and saved h_0001-1-3-6-the_character_2.png to dataset_resized\soggetto1\h\h_0001-1-3-6-the_character_2.png
# Resized and saved h_0001-1-3-9-without_character_4.png to dataset_resized\soggetto1\h\h_0001-1-3-9-without_character_4.png
# Resized and saved h_0001-1-4-0-the_character_2.png to dataset_resized\soggetto1\h\h_0001-1-4-0-the_character_2.png
# Resized and saved h_0001-1-5-3-shadows_character_2.png to dataset_resized\soggetto1\h\h_0001-1-5-3-shadows_character_2.png
# Resized and saved h_0001-1-5-8-with_character_4.png to dataset_resized\soggetto1\h\h_0001-1-5-8-with_character_4.png
# Resized and saved h_0001-1-6-5-then_character_2.png to dataset_resized\soggetto1\h\h_0001-1-6-5-then_character_2.png
# Resized and saved h_0001-1-6-6-have_character_1.png to dataset_resized\soggetto1\h\h_0001-1-6-6-have_character_1.png
# Resized and saved h_0001-1-8-6-should_character_2.png to dataset_resized\soggetto1\h\h_0001-1-8-6-should_character_2.png
# Resized and saved h_0001-1-8-7-have_character_1.png to dataset_resized\soggetto1\h\h_0001-1-8-7-have_character_1.png
# Resized and saved h_0001-1-9-4-now_character_1.png to dataset_resized\soggetto1\h\h_0001-1-9-4-now_character_1.png
# Resized and saved h_0001-1-9-8-has_character_1.png to dataset_resized\soggetto1\h\h_0001-1-9-8-has_character_1.png
# Resized and saved h_0001-2-0-3-his_character_1.png to dataset_resized\soggetto1\h\h_0001-2-0-3-his_character_1.png
# Resized and saved h_0001-2-1-0-Show'd_character_2.png to dataset_resized\soggetto1\h\h_0001-2-1-0-Show'd_character_2.png
# Resized and saved h_0001-2-1-4-whore_character_2.png to dataset_resized\soggetto1\h\h_0001-2-1-4-whore_character_2.png
# Resized and saved h_0001-2-2-5-he_character_1.png to dataset_resized\soggetto1\h\h_0001-2-2-5-he_character_1.png
# Resized and saved h_0001-2-2-7-that_character_2.png to dataset_resized\soggetto1\h\h_0001-2-2-7-that_character_2.png
# Resized and saved h_0001-2-3-0-Disdaining_character_7.png to dataset_resized\soggetto1\h\h_0001-2-3-0-Disdaining_character_7.png
# Resized and saved h_0001-2-3-0-Disdaining_character_9.png to dataset_resized\soggetto1\h\h_0001-2-3-0-Disdaining_character_9.png
# Resized and saved h_0001-2-3-3-with_character_4.png to dataset_resized\soggetto1\h\h_0001-2-3-3-with_character_4.png
# Resized and saved h_0001-2-3-4-his_character_1.png to dataset_resized\soggetto1\h\h_0001-2-3-4-his_character_1.png
# Resized and saved h_0001-2-3-5-brandish'd_character_10.png to dataset_resized\soggetto1\h\h_0001-2-3-5-brandish'd_character_10.png
# Resized and saved h_0001-2-4-0-Which_character_2.png to dataset_resized\soggetto1\h\h_0001-2-4-0-Which_character_2.png
# Resized and saved h_0001-2-4-0-Which_character_5.png to dataset_resized\soggetto1\h\h_0001-2-4-0-Which_character_5.png
# Resized and saved h_0001-2-4-2-with_character_4.png to dataset_resized\soggetto1\h\h_0001-2-4-2-with_character_4.png
# Resized and saved h_0001-2-5-5-his_character_1.png to dataset_resized\soggetto1\h\h_0001-2-5-5-his_character_1.png
# Resized and saved h_0001-2-6-1-he_character_1.png to dataset_resized\soggetto1\h\h_0001-2-6-1-he_character_1.png
# Resized and saved h_0001-2-6-3-the_character_2.png to dataset_resized\soggetto1\h\h_0001-2-6-3-the_character_2.png
# Resized and saved h_0001-3-0-4-nickname_character_1.png to dataset_resized\soggetto1\h\h_0001-3-0-4-nickname_character_1.png
# Resized and saved h_0001-3-2-7-in_character_3.png to dataset_resized\soggetto1\h\h_0001-3-2-7-in_character_3.png
# Resized and saved h_0001-3-3-6-Technology_character_13.png to dataset_resized\soggetto1\h\h_0001-3-3-6-Technology_character_13.png
# Resized and saved h_0001-3-4-2-The_character_2.png to dataset_resized\soggetto1\h\h_0001-3-4-2-The_character_2.png
# Resized and saved h_0001-3-7-0-that_character_2.png to dataset_resized\soggetto1\h\h_0001-3-7-0-that_character_2.png
# Resized and saved h_0001-3-7-1-Whirlwind_character_2.png to dataset_resized\soggetto1\h\h_0001-3-7-1-Whirlwind_character_2.png
# Resized and saved h_0001-3-7-3-Typhoon_character_4.png to dataset_resized\soggetto1\h\h_0001-3-7-3-Typhoon_character_4.png
# Resized and saved h_0001-3-7-5-achieve_character_3.png to dataset_resized\soggetto1\h\h_0001-3-7-5-achieve_character_3.png
# Resized and saved h_0001-3-9-0-The_character_2.png to dataset_resized\soggetto1\h\h_0001-3-9-0-The_character_2.png
# Resized and saved h_0001-4-0-0-When_character_2.png to dataset_resized\soggetto1\h\h_0001-4-0-0-When_character_2.png
# Resized and saved h_0001-4-0-5-individuals_character_2.png to dataset_resized\soggetto1\h\h_0001-4-0-5-individuals_character_2.png
# Resized and saved i_0001-1-0-0-Imagine_character_5.png to dataset_resized\soggetto1\i\i_0001-1-0-0-Imagine_character_5.png
# Resized and saved i_0001-1-0-7-which_character_3.png to dataset_resized\soggetto1\i\i_0001-1-0-7-which_character_3.png
# Resized and saved i_0001-1-0-8-straight_character_5.png to dataset_resized\soggetto1\i\i_0001-1-0-8-straight_character_5.png
# Resized and saved i_0001-1-1-0-Lines_character_3.png to dataset_resized\soggetto1\i\i_0001-1-1-0-Lines_character_3.png
# Resized and saved i_0001-1-1-1-Triangles_character_3.png to dataset_resized\soggetto1\i\i_0001-1-1-1-Triangles_character_3.png
# Resized and saved i_0001-1-10-2-higher_character_2.png to dataset_resized\soggetto1\i\i_0001-1-10-2-higher_character_2.png
# Resized and saved i_0001-1-10-3-views_character_2.png to dataset_resized\soggetto1\i\i_0001-1-10-3-views_character_2.png
# Resized and saved i_0001-1-10-5-things_character_3.png to dataset_resized\soggetto1\i\i_0001-1-10-5-things_character_3.png
# Resized and saved i_0001-1-2-0-figures_character_2.png to dataset_resized\soggetto1\i\i_0001-1-2-0-figures_character_2.png
# Resized and saved i_0001-1-2-2-instead_character_1.png to dataset_resized\soggetto1\i\i_0001-1-2-2-instead_character_1.png
# Resized and saved i_0001-1-2-4-remaining_character_1.png to dataset_resized\soggetto1\i\i_0001-1-2-4-remaining_character_1.png
# Resized and saved i_0001-1-2-4-remaining_character_3.png to dataset_resized\soggetto1\i\i_0001-1-2-4-remaining_character_3.png
# Resized and saved i_0001-1-2-5-fixed_character_2.png to dataset_resized\soggetto1\i\i_0001-1-2-5-fixed_character_2.png
# Resized and saved i_0001-1-2-6-in_character_1.png to dataset_resized\soggetto1\i\i_0001-1-2-6-in_character_1.png
# Resized and saved i_0001-1-3-5-in_character_1.png to dataset_resized\soggetto1\i\i_0001-1-3-5-in_character_1.png
# Resized and saved i_0001-1-3-9-without_character_2.png to dataset_resized\soggetto1\i\i_0001-1-3-9-without_character_2.png
# Resized and saved i_0001-1-4-4-rising_character_2.png to dataset_resized\soggetto1\i\i_0001-1-4-4-rising_character_2.png
# Resized and saved i_0001-1-4-4-rising_character_4.png to dataset_resized\soggetto1\i\i_0001-1-4-4-rising_character_4.png
# Resized and saved i_0001-1-4-9-it_character_1.png to dataset_resized\soggetto1\i\i_0001-1-4-9-it_character_1.png
# Resized and saved i_0001-1-5-2-like_character_2.png to dataset_resized\soggetto1\i\i_0001-1-5-2-like_character_2.png
# Resized and saved i_0001-1-5-8-with_character_2.png to dataset_resized\soggetto1\i\i_0001-1-5-8-with_character_2.png
# Resized and saved i_0001-1-6-0-luminous_character_4.png to dataset_resized\soggetto1\i\i_0001-1-6-0-luminous_character_4.png
# Resized and saved i_0001-1-6-4-will_character_2.png to dataset_resized\soggetto1\i\i_0001-1-6-4-will_character_2.png
# Resized and saved i_0001-1-7-2-notion_character_4.png to dataset_resized\soggetto1\i\i_0001-1-7-2-notion_character_4.png
# Resized and saved i_0001-1-8-8-said_character_4.png to dataset_resized\soggetto1\i\i_0001-1-8-8-said_character_4.png
# Resized and saved i_0001-1-9-1-universe_character_3.png to dataset_resized\soggetto1\i\i_0001-1-9-1-universe_character_3.png
# Resized and saved i_0001-1-9-6-mind_character_2.png to dataset_resized\soggetto1\i\i_0001-1-9-6-mind_character_2.png
# Resized and saved i_0001-2-0-3-his_character_2.png to dataset_resized\soggetto1\i\i_0001-2-0-3-his_character_2.png
# Resized and saved i_0001-2-0-6-smiling_character_4.png to dataset_resized\soggetto1\i\i_0001-2-0-6-smiling_character_4.png
# Resized and saved i_0001-2-0-6-smiling_character_6.png to dataset_resized\soggetto1\i\i_0001-2-0-6-smiling_character_6.png
# Resized and saved i_0001-2-1-1-like_character_2.png to dataset_resized\soggetto1\i\i_0001-2-1-1-like_character_2.png
# Resized and saved i_0001-2-3-0-Disdaining_character_2.png to dataset_resized\soggetto1\i\i_0001-2-3-0-Disdaining_character_2.png
# Resized and saved i_0001-2-3-0-Disdaining_character_6.png to dataset_resized\soggetto1\i\i_0001-2-3-0-Disdaining_character_6.png
# Resized and saved i_0001-2-3-0-Disdaining_character_8.png to dataset_resized\soggetto1\i\i_0001-2-3-0-Disdaining_character_8.png
# Resized and saved i_0001-2-3-3-with_character_2.png to dataset_resized\soggetto1\i\i_0001-2-3-3-with_character_2.png
# Resized and saved i_0001-2-3-4-his_character_2.png to dataset_resized\soggetto1\i\i_0001-2-3-4-his_character_2.png
# ...
# Resized and saved s_0077-4-2-8-strikes_char_0.jpg to dataset_resized\soggetto9\s\s_0077-4-2-8-strikes_char_0.jpg
# Resized and saved s_0077-4-3-0-us_char_1.jpg to dataset_resized\soggetto9\s\s_0077-4-3-0-us_char_1.jpg
# Resized and saved s_0077-4-3-1-is_char_2.jpg to dataset_resized\soggetto9\s\s_0077-4-3-1-is_char_2.jpg
# Resized and saved s_0077-4-5-0-species_char_0.jpg to dataset_resized\soggetto9\s\s_0077-4-5-0-species_char_0.jpg
# Resized and saved s_0077-4-5-1-or_char_1.jpg to dataset_resized\soggetto9\s\s_0077-4-5-1-or_char_1.jpg
# Resized and saved s_0077-4-5-5-state_char_0.jpg to dataset_resized\soggetto9\s\s_0077-4-5-5-state_char_0.jpg
# Resized and saved s_0077-6-0-4-sagen_char_0.jpg to dataset_resized\soggetto9\s\s_0077-6-0-4-sagen_char_0.jpg
# Resized and saved s_0077-6-1-4-so_char_0.jpg to dataset_resized\soggetto9\s\s_0077-6-1-4-so_char_0.jpg
# Resized and saved s_0077-6-2-1-magst_char_3.jpg to dataset_resized\soggetto9\s\s_0077-6-2-1-magst_char_3.jpg
# Resized and saved s_0077-6-2-5-Fesseln_char_5.jpg to dataset_resized\soggetto9\s\s_0077-6-2-5-Fesseln_char_5.jpg
# Resized and saved s_0077-6-2-6-schlagen_char_0.jpg to dataset_resized\soggetto9\s\s_0077-6-2-6-schlagen_char_0.jpg
# Resized and saved s_0077-6-4-4-schallen_char_0.jpg to dataset_resized\soggetto9\s\s_0077-6-4-4-schallen_char_0.jpg
# Resized and saved s_0077-6-5-4-Dienstes_char_5.jpg to dataset_resized\soggetto9\s\s_0077-6-5-4-Dienstes_char_5.jpg
# Resized and saved s_0077-6-5-4-Dienstes_char_7.jpg to dataset_resized\soggetto9\s\s_0077-6-5-4-Dienstes_char_7.jpg
# Resized and saved s_0077-6-6-3-stehn_char_0.jpg to dataset_resized\soggetto9\s\s_0077-6-6-3-stehn_char_0.jpg
# Resized and saved s_0077-6-7-0-Es_char_3.jpg to dataset_resized\soggetto9\s\s_0077-6-7-0-Es_char_3.jpg
# Resized and saved s_0077-6-7-1-sey_char_0.jpg to dataset_resized\soggetto9\s\s_0077-6-7-1-sey_char_0.jpg
# Resized and saved t_0077-1-0-2-vast_char_2.jpg to dataset_resized\soggetto9\t\t_0077-1-0-2-vast_char_2.jpg
# Resized and saved t_0077-1-0-8-straight_char_8.jpg to dataset_resized\soggetto9\t\t_0077-1-0-8-straight_char_8.jpg
# Resized and saved t_0077-1-3-1-about_char_4.jpg to dataset_resized\soggetto9\t\t_0077-1-3-1-about_char_4.jpg
# Resized and saved t_0077-1-3-5-the_char_0.jpg to dataset_resized\soggetto9\t\t_0077-1-3-5-the_char_0.jpg
# Resized and saved t_0077-1-3-7-but_char_2.jpg to dataset_resized\soggetto9\t\t_0077-1-3-7-but_char_2.jpg
# Resized and saved t_0077-1-6-8-notion_char_2.jpg to dataset_resized\soggetto9\t\t_0077-1-6-8-notion_char_2.jpg
# Resized and saved t_0077-1-7-1-country_char_4.jpg to dataset_resized\soggetto9\t\t_0077-1-7-1-country_char_4.jpg
# Resized and saved t_0077-1-7-3-countrymen_char_4.jpg to dataset_resized\soggetto9\t\t_0077-1-7-3-countrymen_char_4.jpg
# Resized and saved t_0077-1-8-7-but_char_2.jpg to dataset_resized\soggetto9\t\t_0077-1-8-7-but_char_2.jpg
# Resized and saved t_0077-2-1-5-but_char_2.jpg to dataset_resized\soggetto9\t\t_0077-2-1-5-but_char_2.jpg
# Resized and saved t_0077-2-1-7-too_char_0.jpg to dataset_resized\soggetto9\t\t_0077-2-1-7-too_char_0.jpg
# Resized and saved t_0077-2-2-6-that_char_2.jpg to dataset_resized\soggetto9\t\t_0077-2-2-6-that_char_2.jpg
# Resized and saved t_0077-2-5-4-out_char_2.jpg to dataset_resized\soggetto9\t\t_0077-2-5-4-out_char_2.jpg
# Resized and saved t_0077-3-0-6-the_char_0.jpg to dataset_resized\soggetto9\t\t_0077-3-0-6-the_char_0.jpg
# Resized and saved t_0077-3-1-4-transistors_char_0.jpg to dataset_resized\soggetto9\t\t_0077-3-1-4-transistors_char_0.jpg
# Resized and saved t_0077-3-3-3-Technology_char_0.jpg to dataset_resized\soggetto9\t\t_0077-3-3-3-Technology_char_0.jpg
# Resized and saved t_0077-3-5-4-the_char_0.jpg to dataset_resized\soggetto9\t\t_0077-3-5-4-the_char_0.jpg
# Resized and saved t_0077-3-6-0-that_char_2.jpg to dataset_resized\soggetto9\t\t_0077-3-6-0-that_char_2.jpg
# Resized and saved t_0077-3-6-3-Typhoon_char_0.jpg to dataset_resized\soggetto9\t\t_0077-3-6-3-Typhoon_char_0.jpg
# Resized and saved t_0077-3-6-6-it_char_2.jpg to dataset_resized\soggetto9\t\t_0077-3-6-6-it_char_2.jpg
# Resized and saved t_0077-3-8-2-Volltransistor-Rechenautomat_char_16.jpg to dataset_resized\soggetto9\t\t_0077-3-8-2-Volltransistor-Rechenautomat_char_16.jpg
# Resized and saved t_0077-3-8-2-Volltransistor-Rechenautomat_char_20.jpg to dataset_resized\soggetto9\t\t_0077-3-8-2-Volltransistor-Rechenautomat_char_20.jpg
# Resized and saved t_0077-3-8-2-Volltransistor-Rechenautomat_char_4.jpg to dataset_resized\soggetto9\t\t_0077-3-8-2-Volltransistor-Rechenautomat_char_4.jpg
# Resized and saved t_0077-4-2-5-first_char_5.jpg to dataset_resized\soggetto9\t\t_0077-4-2-5-first_char_5.jpg
# Resized and saved t_0077-4-3-3-they_char_0.jpg to dataset_resized\soggetto9\t\t_0077-4-3-3-they_char_0.jpg
# Resized and saved t_0077-6-1-3-bist_char_4.jpg to dataset_resized\soggetto9\t\t_0077-6-1-3-bist_char_4.jpg
# Resized and saved t_0077-6-2-1-magst_char_4.jpg to dataset_resized\soggetto9\t\t_0077-6-2-1-magst_char_4.jpg
# Resized and saved t_0077-6-4-3-Todtenglocke_char_4.jpg to dataset_resized\soggetto9\t\t_0077-6-4-3-Todtenglocke_char_4.jpg
# Resized and saved u_0077-1-1-2-Squares_char_2.jpg to dataset_resized\soggetto9\u\u_0077-1-1-2-Squares_char_2.jpg
# Resized and saved u_0077-1-2-0-figures_char_3.jpg to dataset_resized\soggetto9\u\u_0077-1-2-0-figures_char_3.jpg
# Resized and saved u_0077-1-3-1-about_char_3.jpg to dataset_resized\soggetto9\u\u_0077-1-3-1-about_char_3.jpg
# Resized and saved u_0077-1-3-6-surface_char_1.jpg to dataset_resized\soggetto9\u\u_0077-1-3-6-surface_char_1.jpg
# Resized and saved u_0077-1-4-9-much_char_1.jpg to dataset_resized\soggetto9\u\u_0077-1-4-9-much_char_1.jpg
# Resized and saved u_0077-1-5-6-luminous_char_1.jpg to dataset_resized\soggetto9\u\u_0077-1-5-6-luminous_char_1.jpg
# Resized and saved u_0077-1-5-6-luminous_char_6.jpg to dataset_resized\soggetto9\u\u_0077-1-5-6-luminous_char_6.jpg
# Resized and saved u_0077-1-7-1-country_char_2.jpg to dataset_resized\soggetto9\u\u_0077-1-7-1-country_char_2.jpg
# Resized and saved u_0077-1-7-3-countrymen_char_2.jpg to dataset_resized\soggetto9\u\u_0077-1-7-3-countrymen_char_2.jpg
# Resized and saved u_0077-1-8-2-should_char_3.jpg to dataset_resized\soggetto9\u\u_0077-1-8-2-should_char_3.jpg
# Resized and saved u_0077-1-8-7-but_char_1.jpg to dataset_resized\soggetto9\u\u_0077-1-8-7-but_char_1.jpg
# Resized and saved u_0077-2-0-1-fortune_char_3.jpg to dataset_resized\soggetto9\u\u_0077-2-0-1-fortune_char_3.jpg
# Resized and saved u_0077-2-0-5-quarrel_char_1.jpg to dataset_resized\soggetto9\u\u_0077-2-0-5-quarrel_char_1.jpg
# Resized and saved u_0077-2-1-5-but_char_1.jpg to dataset_resized\soggetto9\u\u_0077-2-1-5-but_char_1.jpg
# Resized and saved u_0077-2-4-4-execution_char_3.jpg to dataset_resized\soggetto9\u\u_0077-2-4-4-execution_char_3.jpg
# Resized and saved u_0077-2-5-1-valour's_char_4.jpg to dataset_resized\soggetto9\u\u_0077-2-5-1-valour's_char_4.jpg
# Resized and saved u_0077-2-5-4-out_char_1.jpg to dataset_resized\soggetto9\u\u_0077-2-5-4-out_char_1.jpg
# Resized and saved u_0077-3-1-0-computer_char_4.jpg to dataset_resized\soggetto9\u\u_0077-3-1-0-computer_char_4.jpg
# Resized and saved u_0077-3-2-4-built_char_1.jpg to dataset_resized\soggetto9\u\u_0077-3-2-4-built_char_1.jpg
# Resized and saved u_0077-3-3-1-University_char_0.jpg to dataset_resized\soggetto9\u\u_0077-3-3-1-University_char_0.jpg
# Resized and saved u_0077-3-4-1-builder_char_1.jpg to dataset_resized\soggetto9\u\u_0077-3-4-1-builder_char_1.jpg
# Resized and saved u_0077-3-4-5-quote_char_1.jpg to dataset_resized\soggetto9\u\u_0077-3-4-5-quote_char_1.jpg
# Resized and saved u_0077-3-4-9-computer_char_5.jpg to dataset_resized\soggetto9\u\u_0077-3-4-9-computer_char_5.jpg
# Resized and saved u_0077-3-5-6-calculation_char_3.jpg to dataset_resized\soggetto9\u\u_0077-3-5-6-calculation_char_3.jpg
# Resized and saved u_0077-3-7-7-full_char_1.jpg to dataset_resized\soggetto9\u\u_0077-3-7-7-full_char_1.jpg
# Resized and saved u_0077-4-1-2-sub-variety_char_1.jpg to dataset_resized\soggetto9\u\u_0077-4-1-2-sub-variety_char_1.jpg
# Resized and saved u_0077-4-1-4-our_char_1.jpg to dataset_resized\soggetto9\u\u_0077-4-1-4-our_char_1.jpg
# Resized and saved u_0077-6-0-3-Augenblicke_char_1.jpg to dataset_resized\soggetto9\u\u_0077-6-0-3-Augenblicke_char_1.jpg
# Resized and saved v_0077-1-0-2-vast_char_0.jpg to dataset_resized\soggetto9\v\v_0077-1-0-2-vast_char_0.jpg
# Resized and saved v_0077-1-2-8-move_char_2.jpg to dataset_resized\soggetto9\v\v_0077-1-2-8-move_char_2.jpg
# Resized and saved v_0077-1-4-3-above_char_3.jpg to dataset_resized\soggetto9\v\v_0077-1-4-3-above_char_3.jpg
# Resized and saved v_0077-1-4-8-very_char_0.jpg to dataset_resized\soggetto9\v\v_0077-1-4-8-very_char_0.jpg
# Resized and saved v_0077-1-8-3-have_char_2.jpg to dataset_resized\soggetto9\v\v_0077-1-8-3-have_char_2.jpg
# Resized and saved v_0077-1-8-6-universe_char_3.jpg to dataset_resized\soggetto9\v\v_0077-1-8-6-universe_char_3.jpg
# Resized and saved v_0077-2-2-1-brave_char_2.jpg to dataset_resized\soggetto9\v\v_0077-2-2-1-brave_char_2.jpg
# Resized and saved v_0077-2-2-5-deserves_char_3.jpg to dataset_resized\soggetto9\v\v_0077-2-2-5-deserves_char_3.jpg
# Resized and saved v_0077-2-5-1-valour's_char_0.jpg to dataset_resized\soggetto9\v\v_0077-2-5-1-valour's_char_0.jpg
# Resized and saved v_0077-2-5-3-carved_char_3.jpg to dataset_resized\soggetto9\v\v_0077-2-5-3-carved_char_3.jpg
# Resized and saved v_0077-2-6-4-slave_char_3.jpg to dataset_resized\soggetto9\v\v_0077-2-6-4-slave_char_3.jpg
# Resized and saved v_0077-3-3-0-Vienna_char_0.jpg to dataset_resized\soggetto9\v\v_0077-3-3-0-Vienna_char_0.jpg
# Resized and saved v_0077-3-3-1-University_char_5.jpg to dataset_resized\soggetto9\v\v_0077-3-3-1-University_char_5.jpg
# Resized and saved v_0077-3-8-2-Volltransistor-Rechenautomat_char_0.jpg to dataset_resized\soggetto9\v\v_0077-3-8-2-Volltransistor-Rechenautomat_char_0.jpg
# Resized and saved v_0077-4-0-5-individuals_char_4.jpg to dataset_resized\soggetto9\v\v_0077-4-0-5-individuals_char_4.jpg
# Resized and saved v_0077-4-1-0-variety_char_0.jpg to dataset_resized\soggetto9\v\v_0077-4-1-0-variety_char_0.jpg
# Resized and saved v_0077-4-1-2-sub-variety_char_4.jpg to dataset_resized\soggetto9\v\v_0077-4-1-2-sub-variety_char_4.jpg
# Resized and saved v_0077-4-1-6-cultivated_char_4.jpg to dataset_resized\soggetto9\v\v_0077-4-1-6-cultivated_char_4.jpg
# Resized and saved v_0077-4-5-2-variety_char_0.jpg to dataset_resized\soggetto9\v\v_0077-4-5-2-variety_char_0.jpg
# Resized and saved v_0077-6-1-0-Verweile_char_0.jpg to dataset_resized\soggetto9\v\v_0077-6-1-0-Verweile_char_0.jpg
# Resized and saved v_0077-6-7-6-vorbey_char_0.jpg to dataset_resized\soggetto9\v\v_0077-6-7-6-vorbey_char_0.jpg
# Resized and saved w_0077-1-0-7-which_char_0.jpg to dataset_resized\soggetto9\w\w_0077-1-0-7-which_char_0.jpg
# Resized and saved w_0077-1-4-0-power_char_2.jpg to dataset_resized\soggetto9\w\w_0077-1-4-0-power_char_2.jpg
# Resized and saved w_0077-1-4-6-below_char_3.jpg to dataset_resized\soggetto9\w\w_0077-1-4-6-below_char_3.jpg
# Resized and saved w_0077-1-6-2-will_char_0.jpg to dataset_resized\soggetto9\w\w_0077-1-6-2-will_char_0.jpg
# Resized and saved w_0077-1-8-5-my_char_0.jpg to dataset_resized\soggetto9\w\w_0077-1-8-5-my_char_0.jpg
# Resized and saved w_0077-1-8-8-now_char_2.jpg to dataset_resized\soggetto9\w\w_0077-1-8-8-now_char_2.jpg
# Resized and saved w_0077-2-1-4-whore_char_0.jpg to dataset_resized\soggetto9\w\w_0077-2-1-4-whore_char_0.jpg
# Resized and saved w_0077-2-1-8-weak_char_0.jpg to dataset_resized\soggetto9\w\w_0077-2-1-8-weak_char_0.jpg
# Resized and saved w_0077-2-2-3-well_char_0.jpg to dataset_resized\soggetto9\w\w_0077-2-2-3-well_char_0.jpg
# Resized and saved w_0077-2-4-0-Which_char_0.jpg to dataset_resized\soggetto9\w\w_0077-2-4-0-Which_char_0.jpg
# Resized and saved w_0077-2-4-2-with_char_0.jpg to dataset_resized\soggetto9\w\w_0077-2-4-2-with_char_0.jpg
# Resized and saved w_0077-3-1-1-working_char_0.jpg to dataset_resized\soggetto9\w\w_0077-3-1-1-working_char_0.jpg
# Resized and saved w_0077-3-6-1-Whirlwind_char_0.jpg to dataset_resized\soggetto9\w\w_0077-3-6-1-Whirlwind_char_0.jpg
# Resized and saved w_0077-3-6-1-Whirlwind_char_8.jpg to dataset_resized\soggetto9\w\w_0077-3-6-1-Whirlwind_char_8.jpg
# Resized and saved w_0077-3-7-4-Wiener_char_0.jpg to dataset_resized\soggetto9\w\w_0077-3-7-4-Wiener_char_0.jpg
# Resized and saved w_0077-4-0-0-When_char_0.jpg to dataset_resized\soggetto9\w\w_0077-4-0-0-When_char_0.jpg
# Resized and saved w_0077-4-0-1-we_char_0.jpg to dataset_resized\soggetto9\w\w_0077-4-0-1-we_char_0.jpg
# Resized and saved w_0077-4-2-7-which_char_0.jpg to dataset_resized\soggetto9\w\w_0077-4-2-7-which_char_0.jpg
# Resized and saved x_0077-1-1-4-Hexagons_character_1.png to dataset_resized\soggetto9\x\x_0077-1-1-4-Hexagons_character_1.png
# Resized and saved x_0077-1-2-4-fixed_char_2.jpg to dataset_resized\soggetto9\x\x_0077-1-2-4-fixed_char_2.jpg
# Resized and saved x_0077-2-4-4-execution_character_1.png to dataset_resized\soggetto9\x\x_0077-2-4-4-execution_character_1.png
# Resized and saved y_0077-1-3-0-freely_character_1.png to dataset_resized\soggetto9\y\y_0077-1-3-0-freely_character_1.png
# Resized and saved y_0077-1-4-8-very_char_2.jpg to dataset_resized\soggetto9\y\y_0077-1-4-8-very_char_2.jpg
# Resized and saved y_0077-1-5-2-only_character_1.png to dataset_resized\soggetto9\y\y_0077-1-5-2-only_character_1.png
# Resized and saved y_0077-1-6-6-pretty_character_1.png to dataset_resized\soggetto9\y\y_0077-1-6-6-pretty_character_1.png
# Resized and saved y_0077-1-7-0-my_char_1.jpg to dataset_resized\soggetto9\y\y_0077-1-7-0-my_char_1.jpg
# Resized and saved y_0077-1-7-1-country_char_6.jpg to dataset_resized\soggetto9\y\y_0077-1-7-1-country_char_6.jpg
# Resized and saved y_0077-1-7-7-years_char_0.jpg to dataset_resized\soggetto9\y\y_0077-1-7-7-years_char_0.jpg
# Resized and saved y_0077-1-8-5-my_char_1.jpg to dataset_resized\soggetto9\y\y_0077-1-8-5-my_char_1.jpg
# Resized and saved y_0077-1-9-0-my_char_1.jpg to dataset_resized\soggetto9\y\y_0077-1-9-0-my_char_1.jpg
# Resized and saved y_0077-2-4-3-bloody_char_3.jpg to dataset_resized\soggetto9\y\y_0077-2-4-3-bloody_char_3.jpg
# Resized and saved y_0077-3-1-2-solely_character_1.png to dataset_resized\soggetto9\y\y_0077-3-1-2-solely_character_1.png
# Resized and saved y_0077-3-3-3-Technology_char_8.jpg to dataset_resized\soggetto9\y\y_0077-3-3-3-Technology_char_8.jpg
# Resized and saved y_0077-3-3-4-by_char_1.jpg to dataset_resized\soggetto9\y\y_0077-3-3-4-by_char_1.jpg
# Resized and saved y_0077-4-1-0-variety_character_1.png to dataset_resized\soggetto9\y\y_0077-4-1-0-variety_character_1.png
# Resized and saved y_0077-4-1-2-sub-variety_character_1.png to dataset_resized\soggetto9\y\y_0077-4-1-2-sub-variety_character_1.png
# Resized and saved y_0077-4-3-4-generally_character_1.png to dataset_resized\soggetto9\y\y_0077-4-3-4-generally_character_1.png
# Resized and saved y_0077-4-5-2-variety_character_1.png to dataset_resized\soggetto9\y\y_0077-4-5-2-variety_character_1.png
# Resized and saved y_0077-6-5-5-frey_char_6.jpg to dataset_resized\soggetto9\y\y_0077-6-5-5-frey_char_6.jpg
# Resized and saved y_0077-6-7-1-sey_char_2.jpg to dataset_resized\soggetto9\y\y_0077-6-7-1-sey_char_2.jpg
# Resized and saved y_0077-6-7-6-vorbey_character_1.png to dataset_resized\soggetto9\y\y_0077-6-7-6-vorbey_character_1.png
# Resized and saved z_0077-3-3-6-Zemanek_character_1.png to dataset_resized\soggetto9\z\z_0077-3-3-6-Zemanek_character_1.png
# Resized and saved z_0077-3-3-6-Zemanek_char_0.jpg to dataset_resized\soggetto9\z\z_0077-3-3-6-Zemanek_char_0.jpg
# Resized and saved z_0077-6-0-2-zum_character_1.png to dataset_resized\soggetto9\z\z_0077-6-0-2-zum_character_1.png
# Resized and saved z_0077-6-3-4-zu_character_1.png to dataset_resized\soggetto9\z\z_0077-6-3-4-zu_character_1.png
# Resized and saved z_0077-6-6-5-Zeiger_character_1.png to dataset_resized\soggetto9\z\z_0077-6-6-5-Zeiger_character_1.png
# Resized and saved z_0077-6-7-3-Zeit_character_1.png to dataset_resized\soggetto9\z\z_0077-6-7-3-Zeit_character_1.png

# %%
import os
import shutil

def copy_images(src_path, dest_path):
    # Creiamo la struttura delle cartelle di destinazione
    for letter in "abcdefghiklmnopqrstuvwxyz":
        letter_dir = os.path.join(dest_path, letter)
        os.makedirs(letter_dir, exist_ok=True)

    # Scorriamo le sottocartelle di soggetti
    for subject in os.listdir(src_path):
        subject_path = os.path.join(src_path, subject)
        if os.path.isdir(subject_path):
            # Scorriamo le sottocartelle delle lettere
            for letter in os.listdir(subject_path):
                letter_path = os.path.join(subject_path, letter)
                if os.path.isdir(letter_path) and letter in "abcdefghiklmnopqrstuvwxyz":
                    # Copiamo tutte le immagini nella cartella di destinazione
                    for file_name in os.listdir(letter_path):
                        file_path = os.path.join(letter_path, file_name)
                        if os.path.isfile(file_path) and file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
                            dest_letter_path = os.path.join(dest_path, letter)
                            shutil.copy(file_path, dest_letter_path)

# Esempio di utilizzo
src_path = "dataset"
dest_path = "dataset3"
copy_images(src_path, dest_path)
